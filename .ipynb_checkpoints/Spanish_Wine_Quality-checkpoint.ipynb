# %% [markdown]
# # Spanish Wine Quality

# %% [markdown]
# 1. Source: https://www.kaggle.com/datasets/fedesoriano/spanish-wine-quality-dataset
#
# 2. A list of 7000+ wines that describe their price, rating, and even some flavor description.
#
# 3. Rating
#
# 4. A product produced by a single winery, in a certain year.
#
# 5. Classification
#
# 6. 11
#
# 7. 7500
#
# 8. Wine and type may be hard to deal with.

# %% [markdown]
# Attribute Information
# 1. winery: Winery name
# 2. wine: Name of the wine
# 3. year: Year in which the grapes were harvested
# 4. rating: Average rating given to the wine by the users [from 1-5]
# 5. num_reviews: Number of users that reviewed the wine
# 6. country: Country of origin [Spain]
# 7. region: Region of the wine
# 8. price: Price in euros [€]
# 9. type: Wine variety
# 10. body: Body score, defined as the richness and weight of the wine in your of the wine in your mouth [from 1-5]
# 11. acidity: Acidity score, defined as wine's “pucker” or tartness; it's what makes a wine refreshing and your tongue salivate and want another sip [from 1-5]

# %%
#Imports
import os
os.environ["OMP_NUM_THREADS"] = '1'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import (precision_score,recall_score,mean_absolute_error,
                             mean_squared_error,explained_variance_score,max_error)
from sklearn.preprocessing import (StandardScaler,OrdinalEncoder)
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer,ColumnTransformer,make_column_selector
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:/Users/Mikey/Documents/GitHub/dojo-env-setup/Project-2/imports/wines_SPA.csv')
df.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       7500 non-null   object
#  1   wine         7500 non-null   object
#  2   year         7498 non-null   object
#  3   rating       7500 non-null   float64
#  4   num_reviews  7500 non-null   int64
#  5   country      7500 non-null   object
#  6   region       7500 non-null   object
#  7   price        7500 non-null   float64
#  8   type         6955 non-null   object
#  9   body         6331 non-null   float64
#  10  acidity      6331 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 644.7+ KB

# %%
#Describe
df.describe()
# Out:
#             rating   num_reviews        price         body      acidity
# count  7500.000000   7500.000000  7500.000000  6331.000000  6331.000000
# mean      4.254933    451.109067    60.095822     4.158427     2.946612
# std       0.118029    723.001856   150.356676     0.583352     0.248202
# min       4.200000     25.000000     4.990000     2.000000     1.000000
# 25%       4.200000    389.000000    18.900000     4.000000     3.000000
# 50%       4.200000    404.000000    28.530000     4.000000     3.000000
# 75%       4.200000    415.000000    51.350000     5.000000     3.000000
# max       4.900000  32624.000000  3119.080000     5.000000     3.000000

# %%
#Visual for missing values
plt.style.use('dark_background')
plt.figure(figsize=(10,5))
sns.heatmap(df.isna());

# %%
#Percentages of missing values.
percent_missing=df.isna().sum()*100/len(df)
print(percent_missing)
# Out:
# winery          0.000000
# wine            0.000000
# year            0.026667
# rating          0.000000
# num_reviews     0.000000
# country         0.000000
# region          0.000000
# price           0.000000
# type            7.266667
# body           15.586667
# acidity        15.586667
# dtype: float64

# %%
df['rating'].value_counts()
# Out:
# 4.2    5679
# 4.3     707
# 4.4     484
# 4.5     281
# 4.6     191
# 4.7     112
# 4.8      44
# 4.9       2
# Name: rating, dtype: int64

# %%
rating=df['rating']
def classify_rating(rating):
    if 4.2 <= rating <= 4.4:
        return 'Low Rating'
    elif 4.5 <= rating <= 4.7:
        return 'Middle Rating'
    elif 4.8 <= rating <= 4.9:
        return 'High Rating'
    else:
        return 'NaN'

# %%
df['ratingclass']=df['rating'].apply(classify_rating)
print(df['ratingclass'].value_counts())
# Out:
# Low Rating       6870
# Middle Rating     584
# High Rating        46
# Name: ratingclass, dtype: int64

# %%
#Creating a copy for exploratory data analysis and machine learning
ml_df=df.copy()
eda_df=df.copy()

# %% [markdown]
# #Data Cleaning
#
# *   Some steps will only be performed on the eda_df copy as to prevent data leakage for the ml_df copy.

# %%
len(eda_df.index)
# Out:
# 7500

# %%
#Drop Duplicate rows
ml_df.drop_duplicates()
eda_df.drop_duplicates()
# Out:
#                   winery             wine  year  rating  num_reviews country  \
# 0          Teso La Monja            Tinto  2013     4.9           58  Espana
# 1                 Artadi    Vina El Pison  2018     4.9           31  Espana
# 2           Vega Sicilia            Unico  2009     4.8         1793  Espana
# 3           Vega Sicilia            Unico  1999     4.8         1705  Espana
# 4           Vega Sicilia            Unico  1996     4.8         1309  Espana
# ...                  ...              ...   ...     ...          ...     ...
# 2046         Mustiguillo  Finca Terrerazo  2017     4.2          390  Espana
# 2047         Matarromera     Gran Reserva  2011     4.2          389  Espana
# 2048            Sei Solo         Preludio  2016     4.2          388  Espana
# 2049  Vinedos de Paganos       El Puntido  2005     4.2          384  Espana
# 6100   Remirez de Ganuza     Rioja Blanco  2017     4.2          421  Espana
#
#                 region   price                  type  body  acidity  \
# 0                 Toro  995.00              Toro Red   5.0      3.0
# 1       Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2     Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3     Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4     Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0
# ...                ...     ...                   ...   ...      ...
# 2046      El Terrerazo   24.45                   Red   4.0      3.0
# 2047  Ribera del Duero   64.50  Ribera Del Duero Red   5.0      3.0
# 2048  Ribera del Duero   31.63  Ribera Del Duero Red   5.0      3.0
# 2049             Rioja   73.00             Rioja Red   4.0      3.0
# 6100             Rioja   29.15           Rioja White   NaN      NaN
#
#       ratingclass
# 0     High Rating
# 1     High Rating
# 2     High Rating
# 3     High Rating
# 4     High Rating
# ...           ...
# 2046   Low Rating
# 2047   Low Rating
# 2048   Low Rating
# 2049   Low Rating
# 6100   Low Rating
#
# [2048 rows x 12 columns]

# %%
len(eda_df.index)
# Out:
# 7500

# %%
#NaN Values
eda_df.isna().sum()
# Out:
# winery            0
# wine              0
# year              2
# rating            0
# num_reviews       0
# country           0
# region            0
# price             0
# type            545
# body           1169
# acidity        1169
# ratingclass       0
# dtype: int64

# %%
#Country is all 1.
eda_df['country'].value_counts()
ml_df['country'].value_counts()
# Out:
# Espana    7500
# Name: country, dtype: int64

# %%
#dropping as this info is not needed for our exploration of the data.
ml_df.drop(columns='country',inplace=True)
eda_df.drop(columns='country',inplace=True)

# %%
#Year has missing values and is listed as an object. Setting max rows to find errors.
pd.set_option('display.max_rows',None)
eda_df['year'].value_counts()
# Out:
# 2011    1190
# 2016     897
# 2015     860
# 2018     850
# 2017     731
# 2012     528
# 2020     474
# 2014     376
# 2019     331
# N.V.     288
# 2004     254
# 2005     198
# 2010      74
# 2013      66
# 2009      46
# 2007      38
# 2006      32
# 2008      30
# 2001      21
# 2000      18
# 1994      13
# 1995      13
# 2003      13
# 1998      12
# 2002      12
# 1996      11
# 1999      10
# 1982       8
# 1964       7
# 1989       7
# 1985       7
# 2021       6
# 1987       6
# 1986       6
# 1968       5
# 1970       5
# 1981       4
# 1997       3
# 1991       3
# 1973       3
# 1955       2
# 1965       2
# 1959       2
# 1980       2
# 1983       2
# 1988       2
# 1975       2
# 1962       2
# 1990       2
# 1979       2
# 1946       2
# 1951       1
# 1928       1
# 1929       1
# 1976       1
# 1949       1
# 1922       1
# 1978       1
# 1969       1
# 1942       1
# 1954       1
# 1961       1
# 1910       1
# 1967       1
# 1992       1
# 1958       1
# 1953       1
# 1972       1
# 1974       1
# 1931       1
# 1925       1
# Name: year, dtype: int64

# %%
#Replacing N.V. with NaN, dropping them, converting year to int
eda_df['year']=eda_df['year'].replace('N.V.',np.nan)
eda_df=eda_df.dropna(subset=['year'])
eda_df['year']=eda_df['year'].astype('int64')

#ML copy
ml_df['year']=ml_df['year'].replace('N.V.',np.nan)
ml_df=ml_df.dropna(subset=['year'])
ml_df['year']=ml_df['year'].astype('int64')

# %%
eda_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7210 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       7210 non-null   object
#  1   wine         7210 non-null   object
#  2   year         7210 non-null   int64
#  3   rating       7210 non-null   float64
#  4   num_reviews  7210 non-null   int64
#  5   region       7210 non-null   object
#  6   price        7210 non-null   float64
#  7   type         6672 non-null   object
#  8   body         6070 non-null   float64
#  9   acidity      6070 non-null   float64
#  10  ratingclass  7210 non-null   object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 675.9+ KB

# %%
eda_df.isna().sum()
# Out:
# winery            0
# wine              0
# year              0
# rating            0
# num_reviews       0
# region            0
# price             0
# type            538
# body           1140
# acidity        1140
# ratingclass       0
# dtype: int64

# %%
#Filling NaN values for body, acidity, and type. Using median for this just for data exploration
eda_df['body']=eda_df['body'].fillna(eda_df.groupby('rating')['body'].transform('median'))
eda_df['acidity']=eda_df['acidity'].fillna(eda_df.groupby('rating')['acidity'].transform('median'))
eda_df['type']=eda_df['type'].fillna(df['type'].mode())

# %%
#Looking at value_counts for categorical columns
features=['winery','wine','region','type']
for feature in features:
    counts=eda_df[feature].value_counts()
    print(f"Value counts for {feature}:")
    print(counts)
    print()
# Out:
# Value counts for winery:
# Contino                                             457
# Artadi                                              261
# La Rioja Alta                                       254
# Sierra Cantabria                                    237
# Matarromera                                         232
# Vina Pedrosa                                        230
# Imperial                                            228
# Losada                                              227
# Ramon Bilbao                                        225
# Sei Solo                                            225
# Portal del Priorat                                  225
# Matsu                                               224
# Bodegas La Horra                                    223
# Campillo                                            223
# Conreria d'Scala Dei                                223
# La Vicalanda                                        223
# Mustiguillo                                         222
# Mar de Frades                                       222
# Enrique Mendoza                                     220
# Clos Pons                                           220
# Ramon do Casar                                      220
# Binigrau                                            220
# Vinedos de Paganos                                  175
# Vega Sicilia                                         96
# Remirez de Ganuza                                    79
# Alvaro Palacios                                      48
# Marques de Murrieta                                  33
# Dominio de Pingus                                    31
# Martinet                                             30
# Abadia Retuerta                                      27
# Emilio Moro                                          25
# Vina Sastre                                          25
# Bodegas Roda                                         23
# Muga                                                 23
# Toro Albala                                          23
# Bodega Contador (Benjamin Romeo)                     21
# Marques de Riscal                                    21
# Clos Mogador                                         20
# Pago de Los Capellanes                               19
# Familia Torres                                       19
# Bodegas Mauro                                        18
# Teso La Monja                                        17
# Alion                                                16
# Arzuaga                                              16
# Bodega Numanthia                                     14
# Allende                                              14
# Pintia                                               14
# Tinto Pesquera                                       14
# Bodegas Valduero                                     14
# Bodegas Mas Alta                                     14
# Hacienda Monasterio                                  14
# R. Lopez de Heredia                                  13
# Mas Doix                                             13
# Remelluri                                            13
# Carmelo Rodero                                       13
# Bodegas El Nido                                      13
# Aalto                                                12
# Castillo Perelada                                    12
# Recaredo                                             12
# Pago de Carraovejas                                  11
# Vinicola Real                                        11
# Protos                                               11
# Clos Erasmus                                         11
# Alto Moncayo                                         10
# Gramona                                              10
# Terroir Al Limit Soc. Lda                            10
# Ferrer Bobet                                         10
# Scala Dei                                            10
# Benjamin de Rothschild - Vega Sicilia                10
# Lan                                                   9
# Enate                                                 9
# Bodegas San Roman                                     9
# Anima Negra                                           9
# Descendientes de J. Palacios                          8
# Vall Llach                                            8
# Marques de Caceres                                    8
# Dominio del Aguila                                    8
# Pujanza                                               8
# Tomas Postigo                                         8
# Bodegas Amaren                                        8
# Mas d'en Gil                                          7
# Juan Gil                                              7
# Ossian                                                7
# Bodegas Faustino                                      7
# Dominio de Atauta                                     7
# Vizcarra                                              7
# Costers del Siurana                                   6
# Cims de Porrera                                       6
# Espectacle del Montsant                               6
# Telmo Rodriguez                                       6
# Volver                                                6
# Tridente                                              6
# Gomez Cruzado                                         6
# Marques de Vargas                                     6
# Senorio de San Vicente                                6
# Dominio del Bendito                                   5
# Jimenez-Landi                                         5
# Dominio de Es                                         5
# Agusti Torello Mata                                   5
# Pago de Vallegarcia                                   5
# Finca Torremilanos                                    5
# Rafael Palacios                                       5
# Bosque de Matasnos                                    5
# Garmon                                                5
# Ordonez                                               5
# Bodegas 6o Elemento - Vino Sexto Elemento             5
# Atalaya                                               5
# Merum Priorati                                        4
# Los Aguilares                                         4
# Vina Pomal                                            4
# Vinyes Domenech                                       4
# Luis Canas                                            4
# Dominio de Cair                                       4
# Clos Galena                                           4
# Morca                                                 4
# Abel Mendoza Monge                                    4
# Torre de Ona                                          4
# Figuero                                               4
# Pazo Senorans                                         4
# De Moya                                               4
# Bodegas Celler Francisco Castillo - Clos Dominic      4
# Quinta Sardonia                                       4
# Pradorey                                              4
# Valderiz                                              4
# Jose Pariente                                         4
# Terras Gauda                                          4
# Finca Villacreces                                     4
# Bodegas Ximenez-Spinola                               4
# Tresmano - Tr3smano                                   4
# Castano                                               4
# Tobia                                                 4
# Dehesa de Los Canonigos                               4
# Belondrade                                            4
# Terra Remota                                          4
# Castell d'Encus                                       4
# Huerta de Albala                                      4
# Adama Wines                                           4
# Territorio Luthier                                    4
# Clos Figueras                                         4
# Oxer Wines                                            4
# Bodegas Naluar & Acediano                             4
# Alta Alella                                           4
# Jaro                                                  4
# Chivite                                               4
# Marques de Grinon                                     4
# Casa Castillo                                         4
# Vinas del Vero                                        4
# Bodegas Vilano                                        4
# Miguel Merino                                         4
# Montecastro                                           3
# Gutierrez de la Vega                                  3
# Ausas                                                 3
# Ysios                                                 3
# Bodega Tameran                                        3
# Castillo de Cuzcurrita                                3
# Cepa 21                                               3
# Barahonda                                             3
# Pedralonga                                            3
# Antidoto                                              3
# Nin-Ortiz                                             3
# Carlos Moro                                           3
# Hacienda Solano                                       3
# Venus la Universal                                    3
# Abadal                                                3
# Altos de Rioja                                        3
# Valquejigoso                                          3
# Comenge                                               3
# Penafiel                                              3
# Dehesa del Carrizal                                   3
# VALENCISO                                             3
# Cervoles                                              3
# Monte Real                                            3
# Baigorri                                              3
# Arinzano                                              3
# Raul Perez                                            3
# Enric Soler                                           3
# Finca Rio Negro                                       3
# Ostatu                                                3
# Legaris                                               3
# Llopart                                               3
# Clos d'Agon                                           3
# Cruz de Alba                                          3
# Sebio                                                 3
# Albet i Noya                                          2
# Leda                                                  2
# Cal Batllet - Celler Ripoll Sans                      2
# Do Ferreiro (Bodegas Gerardo Mendez)                  2
# Venta Las Vacas                                       2
# Vinedos Hermanos Hernaiz                              2
# Pago Calzadilla                                       2
# Martin Codax                                          2
# Finca Valpiedra                                       2
# Rodriguez de Vera                                     2
# Vivanco                                               2
# Valtravieso                                           2
# Hispano Suizas                                        2
# El Coto                                               2
# Zifar                                                 2
# Bodega Juan Carlos Sancha                             2
# Bodegas Gama                                          2
# Bodegas Reyes                                         2
# Atlan & Artisan                                       2
# Cartoixa de Montsalvat                                2
# Real de Asua                                          2
# Juve & Camps                                          2
# Can Rafols dels Caus                                  2
# Josep Grau Viticultor                                 2
# Bodegas Ochoa                                         2
# Bodega Otazu                                          2
# Avgvstvs                                              2
# Bodegas Luis Perez                                    2
# Habla                                                 2
# Celler de Capcanes                                    2
# Marti Fabra                                           2
# Neo                                                   2
# Bodega Campo Eliseo                                   2
# Quinta de la Quietud                                  2
# Taron                                                 2
# Bodega Tesalia                                        2
# Marques de Tomares                                    2
# Avancia                                               2
# Aster                                                 2
# Llanos Negros                                         2
# Bodegas Frontonio                                     2
# Lopez Cristobal                                       2
# Jorge Ordonez                                         2
# Bodega Elias Mora                                     2
# Bodega Ribas                                          2
# Marco Abella                                          2
# Beronia                                               2
# Pago de Larrainzar                                    2
# Ukan Winery                                           2
# Astrales                                              2
# Trus                                                  2
# Finca Moncloa                                         2
# Orben                                                 2
# Francisco Barona                                      2
# Javier Sanz Viticultor                                2
# Dominio do Bibei                                      2
# Bodegas Frontaura                                     2
# Pazo Barrantes                                        2
# Bodegas Aragonesas                                    2
# El Regajal                                            2
# Perinet                                               2
# Altanza                                               2
# Bodega de Bardos                                      2
# Cillar de Silos                                       2
# Gonzalez-Byass                                        2
# Anayon                                                2
# Hacienda Lopez de Haro                                2
# Jesus Madrazo                                         2
# Resalte                                               2
# Eulogio Pomares                                       2
# Luis A. Rodriguez Vazquez                             2
# Ontanon                                               2
# Sangenis I Vaque                                      2
# Alonso del Yerro                                      2
# Cal Pla                                               2
# Pinea                                                 2
# Sara Perez y Rene Barbier                             2
# Casa Rojo                                             2
# Chozas Carrascal                                      2
# Tarsus                                                2
# Mestres                                               2
# Jorge Piernas                                         1
# Espelt                                                1
# Gallina de Piel                                       1
# Arid                                                  1
# Bodegas Arrocal                                       1
# Milsetentayseis                                       1
# l'Infernal Combier Fischer Gerin                      1
# Hugas de Batlle                                       1
# Attis                                                 1
# Buil & Gine                                           1
# Guilera                                               1
# Castell del Remei                                     1
# Valdubon                                              1
# Mas de les Pereres                                    1
# San Cobate                                            1
# Lar de Paula                                          1
# Lambuena                                              1
# Javi Revert                                           1
# Shaya                                                 1
# Loxera                                                1
# Dominio Fournier                                      1
# Valserrano                                            1
# Neton                                                 1
# Bodega Aida i Luis                                    1
# El Lagar de Isilla                                    1
# Anibal de Otero                                       1
# Altos del Enebro                                      1
# Albamar                                               1
# Can Bas                                               1
# Vinyes dels Aspres                                    1
# Atlantida                                             1
# Emilio Rojo                                           1
# Olivardots                                            1
# La Val                                                1
# Tres Piedras                                          1
# Bodegas Y Vinedos Alilian                             1
# Roig Parals                                           1
# Goyo Garcia Viadero                                   1
# Santiago Ruiz                                         1
# Vina Real                                             1
# Bordalas Garcia                                       1
# Rimarts                                               1
# Pinna Fidelis                                         1
# Loess                                                 1
# Dominio de Anza                                       1
# Samsara                                               1
# Cuentavinas                                           1
# Casal de Arman                                        1
# Proyecto Garnachas de Espana                          1
# Baluarte                                              1
# La Legua                                              1
# Murviedro                                             1
# Diez Caballero                                        1
# Vegalfaro                                             1
# Palacios Remondo                                      1
# Bohorquez                                             1
# Adega Familiar Eladio Pineiro                         1
# Culebron                                              1
# Francisco Garcia Perez                                1
# Dominio de Calogia                                    1
# Dominio de Loalva                                     1
# Cepas Familiares                                      1
# Vinyes del Terrer                                     1
# Mandia Vell                                           1
# Mauro Estevez                                         1
# Mas Bertran                                           1
# Acustic Celler                                        1
# Edetaria                                              1
# Hacienda Zorita Natural Reserve                       1
# Ton Rimbau                                            1
# Dominio de la Vega                                    1
# A Coroa                                               1
# Alonso & Pedrajo                                      1
# Valdecuevas                                           1
# Navajas                                               1
# Algueira                                              1
# Mocen                                                 1
# Estones                                               1
# Micro Bio (MicroBio)                                  1
# Inurrieta                                             1
# Flor de Chasna                                        1
# Lagar de Sabariz                                      1
# Naia                                                  1
# AGE                                                   1
# Can Xanet                                             1
# Paco & Lola                                           1
# Vinas del Cenit                                       1
# Mas Blanch I Jove                                     1
# Barco del Corneta                                     1
# Joan d'Anguera                                        1
# Xaloc                                                 1
# Ladairo                                               1
# Traslascuestas                                        1
# Bodega Rento                                          1
# Codorniu                                              1
# Sota els Angels                                       1
# Berceo                                                1
# Carlos Serres                                         1
# Bodegas Casa Primicia                                 1
# David Moreno                                          1
# Edra                                                  1
# Valdelosfrailes                                       1
# Briego                                                1
# Guillem Carol - Cellers Carol Valles                  1
# Monovar                                               1
# Particular                                            1
# Bodegas Asenjo & Manso                                1
# Rodriguez Sanzo                                       1
# Castell Miquel                                        1
# Galindo San Millan                                    1
# Ramos-Paul                                            1
# Murua                                                 1
# Mas Llunes                                            1
# Can Axartell                                          1
# Joan Simo                                             1
# Es Fangar                                             1
# Bodegas Monte La Reina                                1
# Portia                                                1
# Mas Perinet                                           1
# Vivaltus                                              1
# Collbaix Celler El Moli                               1
# Olivier Riviere                                       1
# Farina                                                1
# Bodegas Tierra                                        1
# Fefinanes                                             1
# Freixenet                                             1
# Azpilicueta                                           1
# Veronica Salgado                                      1
# Bodegas Imperiales - Abadia de San Quirce             1
# Marta Mate                                            1
# Bodegas El Paraguas                                   1
# Museum                                                1
# Condado de Haza                                       1
# La Vinya del Vuit                                     1
# Mas del Serral                                        1
# Pago del Vostal                                       1
# Noelia Bebelia                                        1
# Veigamoura                                            1
# Palmeri Sicilia                                       1
# Mas Que Vinos                                         1
# Bodegas Estraunza                                     1
# Pittacum                                              1
# Bodega Sommos                                         1
# Marques de la Concordia                               1
# Vina al Lado de la Casa                               1
# Divina Proporcion                                     1
# Terra d'Uro                                           1
# Costers del Priorat                                   1
# Oller del Mas                                         1
# Bodegas Clunia                                        1
# Virgen de la Asuncion                                 1
# Ca l'Apotecari                                        1
# Marques de Burgos                                     1
# Fos                                                   1
# Hacienda Grimon                                       1
# Capafons-Osso                                         1
# Zarate                                                1
# Federico Paternina                                    1
# Cerro San Cristobal                                   1
# Amos Baneres                                          1
# Vinos Sanz                                            1
# Hermanos Pecina                                       1
# Biniagual                                             1
# Breca                                                 1
# Sierra Salinas                                        1
# Bodegas Valdelana                                     1
# Pazo de Rubianes                                      1
# Godeval                                               1
# Bodegas Olarra                                        1
# Sonsierra                                             1
# Pepe Mendoza Casa Agricola                            1
# Vins Miquel Gelabert                                  1
# El Grillo y La Luna                                   1
# Altos del Terral                                      1
# Jean Leon                                             1
# Bodegas Ateca                                         1
# Uvaguilera Aguilera                                   1
# Fernandez de Pierola                                  1
# De Muller                                             1
# Monteabellon                                          1
# Martinez Lacuesta                                     1
# Name: winery, dtype: int64
#
# Value counts for wine:
# Reserva                                                                   467
# Gran Reserva                                                              458
# Rioja Reserva                                                             240
# El Viejo                                                                  224
# Corimbo I                                                                 223
# Valdegines                                                                223
# Mirto                                                                     223
# Rioja Graciano                                                            223
# Preludio                                                                  222
# Altos de Losada                                                           222
# Clos del Portal Somni                                                     222
# Coleccion Privada                                                         222
# Vina Alberdi Crianza                                                      221
# Finca Terrerazo                                                           221
# Gran Reserva Rioja                                                        221
# Santa Rosa                                                                220
# Roc Nu                                                                    220
# Rias Baixas Albarino Finca Valinas                                        220
# Treixadura                                                                220
# Nounat                                                                    220
# Les Brugueres                                                             220
# El Puntido                                                                169
# Rioja Blanco                                                               67
# Tinto                                                                      56
# Unico                                                                      41
# Valbuena 5o                                                                32
# Priorat                                                                    26
# Ribera del Duero                                                           24
# Unico Reserva Especial Edicion                                             23
# Rioja Gran Reserva                                                         21
# L'Ermita Velles Vinyes Priorat                                             18
# Pingus                                                                     17
# Finca Dofi                                                                 17
# Vina El Pison                                                              16
# Clos Martinet                                                              15
# Toro                                                                       14
# Castillo Ygay Gran Reserva Especial Tinto                                  12
# Cami Pesseroles                                                            11
# Rioja Gran Reserva 904                                                     11
# Roda I Reserva Rioja                                                       11
# Dalmau Rioja                                                               10
# La Cueva del Contador Rioja                                                10
# Flor de Pingus                                                             10
# Prado Enea Gran Reserva                                                    10
# Crianza                                                                     9
# Regina Vides Ribera del Duero                                               9
# Amancio                                                                     8
# Doix                                                                        8
# Vina Ardanza Reserva                                                        8
# Gran Reserva 890                                                            8
# Termanthia                                                                  8
# Pesus Ribera del Duero                                                      8
# Don PX Pedro Ximenez                                                        7
# Roda Reserva Rioja                                                          7
# Garnacha                                                                    7
# El Nido                                                                     7
# Finca el Bosque                                                             7
# Seleccion Especial                                                          7
# Victorino                                                                   7
# Vina del Olivo                                                              7
# Contador Rioja                                                              6
# Torre Muga                                                                  6
# San Vicente Rioja                                                           6
# Clio                                                                        6
# Gaudium                                                                     6
# Petit Verdot                                                                6
# Son Negre                                                                   6
# Calvario Rioja                                                              6
# El Carretil                                                                 6
# Baron de Chirel Rioja Reserva                                               6
# La Poza de Ballesteros                                                      6
# Trasnocho                                                                   6
# Les Manyes                                                                  6
# Malleolus de Sanchomartin                                                   6
# Vi de Vila Gratallops                                                       6
# Parcela El Picon Tinto                                                      6
# Cosecha                                                                     6
# Don PX Convento Seleccion                                                   6
# PS (Pagos Seleccionados) Ribera del Duero                                   6
# Pago de Santa Cruz                                                          6
# Numanthia                                                                   6
# A Mano Rioja                                                                5
# Classic                                                                     5
# Pago Negralada                                                              5
# Malleolus                                                                   5
# I Gran Reserva                                                              5
# Vinas Viejas de Soria Ribera Del Duero                                      5
# Aurus                                                                       5
# Le Domaine Blanco de Guarda                                                 5
# Grans Muralles                                                              5
# Seleccio Especial Vinyes Velles                                             5
# Macan                                                                       5
# Perez Pascuas Gran Reserva Seleccion                                        5
# Cirsion Rioja                                                               5
# Vinas Viejas Verdejo                                                        5
# Gran Reserva Rioja (Finca Ygay)                                             5
# Terreus Paraje de Cueva Baja                                                5
# Cava Kripta Gran Reserva Brut Nature                                        5
# VS                                                                          5
# Macan Clasico                                                               5
# 200 Monges Rioja Reserva                                                    5
# Reserva Tinto                                                               5
# Red                                                                         5
# Clos Fonta Priorat                                                          5
# Chafandin                                                                   4
# Ribera del Duero Reserva                                                    4
# Ribera del Duero TSM                                                        4
# Reserva Ribera del Duero                                                    4
# Ribera del Duero Una Cepa I                                                 4
# Vinyes Altes Porrera                                                        4
# Cava Celler Batlle                                                          4
# QS                                                                          4
# Seleccion Especial (Reserva)                                                4
# Clos Figueres                                                               4
# La Nieta                                                                    4
# Seleccion Finca el Grajo Viejo                                              4
# Granja Gran Reserva Rioja                                                   4
# PSI                                                                         4
# Pago Valdebellon                                                            4
# La Bienquerida                                                              4
# Ribera del Duero Crianza                                                    4
# Porrera Vi de Vila                                                          4
# La Basseta                                                                  4
# Pagos Viejos                                                                4
# Priorat Vinyes Velles                                                       4
# Acediano                                                                    4
# Rejon Tempranillo                                                           4
# Jumilla Blue Label                                                          4
# Malleolus de Valderramiro                                                   4
# Vina Tondonia Reserva                                                       4
# Nebro Ribera del Duero                                                      4
# Finca Malaveina                                                             4
# Mas La Plana Cabernet Sauvignon                                             4
# Grandes Anadas Rioja                                                        4
# Serral del Vell Brut Nature                                                 4
# Belondrade y Lurton                                                         4
# Aquilon Garnacha                                                            4
# 5o Ano Ribera del Duero Tinto                                               4
# La Creu Alta                                                                4
# Don PX Seleccion                                                            4
# Blecua Somontano                                                            4
# Casa Cisca Monastrell                                                       4
# 1902 Centenary Carignan Priorat                                             4
# Reserva Especial                                                            4
# Culmen Reserva Rioja                                                        3
# Bosque de Matasnos Etiqueta Blanca                                          3
# V2 Tinto                                                                    3
# Triga                                                                       3
# El Titan del Bendito                                                        3
# Cantos del Diablo                                                           3
# Galena                                                                      3
# Pago De Valtarrena                                                          3
# Interpretacion                                                              3
# Vendimia                                                                    3
# Gran Reserva Penas Aladas                                                   3
# Tempranillo Reserva                                                         3
# Vina Arana Gran Reserva                                                     3
# Vatan Tinta de Toro                                                         3
# Vinas Viejas                                                                3
# Vina Tondonia Gran Reserva                                                  3
# Ribera del Duero Red                                                        3
# Clos de L'Obac                                                              3
# Rioja Cisma                                                                 3
# Vina Bosconia Reserva                                                       3
# 3er Ano Ribera del Duero Tinto                                              3
# Ribera del Duero Torralvo                                                   3
# Vendimia Seleccionada                                                       3
# Don PX Gran Reserva                                                         3
# Llanos del Almendro Ribera del Duero                                        3
# 27 Ribera del Duero                                                         3
# Parcela El Nogal Tinto                                                      3
# Cartago Paraje de Pozo                                                      3
# Alabaster                                                                   3
# Alaya Tierra (Old Vines Vieilles Vignes)                                    3
# Teixar                                                                      3
# Las Lamas Bierzo (Corullon)                                                 3
# Nun Vinya dels Taus                                                         3
# Aro                                                                         3
# Ribera Del Duero Reserva Premium 6 Anos                                     3
# An                                                                          3
# Clon De La Familia                                                          3
# Blanco                                                                      3
# Gran Vino Blanco                                                            3
# Cuesta de Las Liebres                                                       3
# Rioja Norte                                                                 3
# Turo d'en Mota                                                              3
# Les Tosses                                                                  3
# Finca Los Hoyales Ribera del Duero                                          3
# Godello Blanco                                                              3
# Els Escurcons                                                               3
# Pago Garduna                                                                3
# Pie Franco                                                                  3
# Sofia                                                                       3
# 3.9                                                                         3
# Gran Reserva Ribera del Duero                                               3
# Purgatori Costers del Segre                                                 3
# Masdeu                                                                      3
# Bruto                                                                       3
# As Sortes Val do Bibei Godello                                              3
# Crianza Tinto                                                               3
# Millenium Reserva                                                           3
# La Faraona Bierzo (Corullon)                                                3
# Ribera del Duero Prestigio                                                  3
# Montes Obarenes Seleccion Terroir                                           3
# Seleccion de Anada Albarino Rias Baixas                                     3
# Chardonnay Fermentado en Barrica                                            3
# Reserva Rioja (Finca Ygay)                                                  3
# Idus                                                                        3
# Marmajuelo                                                                  2
# Pinot Noir                                                                  2
# Vina Alberdi Reserva                                                        2
# Octogenarius                                                                2
# Emporda Aires de Garbet                                                     2
# Rias Baixas Albarino Atlantico                                              2
# Reserva 5 Ano                                                               2
# Malpuesto                                                                   2
# Corpinnat Terrers Brut Nature                                               2
# Terras Gauda O Rosal                                                        2
# Coto de Imaz Rioja Gran Reserva                                             2
# El Anejon                                                                   2
# La Vina de Andres Romeo Rioja                                               2
# Taberner Tierra de Cadiz                                                    2
# El Cel                                                                      2
# Clos del Portal Negre de Negres                                             2
# Delicado Cosecha Pedro Ximenez                                              2
# Salmos                                                                      2
# Christina Ribera del Duero                                                  2
# Perpetual                                                                   2
# Heretge Priorat                                                             2
# Gessami                                                                     2
# La Atalaya del Camino                                                       2
# Veraton Garnacha                                                            2
# Bassus Pinot Noir                                                           2
# Gloria Rioja                                                                2
# Montes de Toledo Syrah                                                      2
# Malvasia                                                                    2
# Clos Adrien                                                                 2
# El Rocallis                                                                 2
# Reserva Seleccion de la Familia                                             2
# Albarino Pedralonga                                                         2
# Vendimia Tardia Moscatel                                                    2
# Reserva XR                                                                  2
# Alicante Bouschet by Tarima                                                 2
# Dominio de Atauta                                                           2
# Martelo Reserva                                                             2
# Laurel                                                                      2
# Artigas                                                                     2
# Matallana                                                                   2
# Capellania Reserva                                                          2
# Masia Carreras Negre                                                        2
# Finca El Otero                                                              2
# Pla dels Angels Rosado                                                      2
# Suzzane Rioja                                                               2
# Finca Cuesta Clara Raro Reserva                                             2
# Prieto Picudo                                                               2
# Venus                                                                       2
# Albarino                                                                    2
# La Mar                                                                      2
# Elite                                                                       2
# Massipa de Scala Dei Garnatxa Blanca - Xenin                                2
# 5o Ano                                                                      2
# Clos Monlleo                                                                2
# Seleccion                                                                   2
# La Solana Alta                                                              2
# Hipperia Red Blend                                                          2
# Maria Ribera del Duero                                                      2
# Salvaxe                                                                     2
# La Revelia Godello                                                          2
# Dolc Mataro                                                                 2
# Seleccion Privada                                                           2
# Malabrigo Ribera del Duero                                                  2
# No. 2 Victoria                                                              2
# Manyetes                                                                    2
# Ines                                                                        2
# Pago El Espino                                                              2
# Alto de la Caseta                                                           2
# Martires Rioja                                                              2
# Cava Original Brut (Espumos)                                                2
# Marti Reserva Penedes                                                       2
# Teofilo Reyes Crianza                                                       2
# Cepas Vellas Rias Baixas Albarino                                           2
# Summum Monastrell                                                           2
# De Garage Rioja                                                             2
# Montsalvat                                                                  2
# Gran Calzadilla                                                             2
# Voltons                                                                     2
# Godello                                                                     2
# La Cuartilleja Reserva                                                      2
# Hispania                                                                    2
# Usted                                                                       2
# Finca Las Comas Verdejo                                                     2
# Torremilanos Coleccion Ribera del Duero                                     2
# Cerrado del Castillo Rioja                                                  2
# Les Aubaguetes Priorat                                                      2
# ...
# Gran Ribera del Duero                                                       1
# Whisba Tempranillo Aged 18 Months in Whisky Barrels                         1
# Edicion Limitada                                                            1
# Albarino de Fefinanes III Ano                                               1
# Lealtanza Coleccion de Artistas Espanoles Sorolla                           1
# Gran Reserva Classica Tinto                                                 1
# Desti                                                                       1
# Cuvee Old Vines Unfiltered                                                  1
# Vinos Singulares Tempranillo Blanco Reserva                                 1
# Fondillon                                                                   1
# Quincha Corral                                                              1
# Atlantico                                                                   1
# Tadeo Tinto                                                                 1
# Gran Reserva Rosado                                                         1
# Altos R Pigeage Nacido en Barrica Blanco                                    1
# Maceracion Con Pieles                                                       1
# Dominio del Verso Red Blend                                                 1
# Grano a Grano Graciano - Garnacha                                           1
# Aponte Winemaker's Private Collection Tempranillo                           1
# Diables                                                                     1
# Finca Butaros Vinya Centenaria                                              1
# 5V Blanco                                                                   1
# La Comtesse de Pazo Barrantes Albarino                                      1
# The Artist                                                                  1
# Gran Reserva Classica Blanco                                                1
# Les Eres Vinyes Velles                                                      1
# Toro 2V Premium                                                             1
# St Antoni de Scala Dei Priorat                                              1
# Seda de Oro Reserva                                                         1
# Queiron Reserva Vinedos Familiares                                          1
# Finca La Colina Sauvignon Blanc                                             1
# Castillo de Monte la Reina Cuvee Privee                                     1
# Carraquintana de Amaren                                                     1
# Garnacha Parcela 81 Vinas Viejas                                            1
# Cava Enoteca Finca de L'Origen Brut Nature                                  1
# Salinas 1237                                                                1
# Premium                                                                     1
# El Cabernet F - Familiar                                                    1
# Cabernet Sauvignon                                                          1
# Vina de Martin Escolma Ribeiro                                              1
# Perinet + Plus                                                              1
# Rioja Reserva 10 Anos Despues Edicion Limitada                              1
# Gallaecia Rias Baixes Albarino                                              1
# Verdejo                                                                     1
# Vallegarcia Viognier                                                        1
# Campo Eliseo                                                                1
# Atteca Armas Garnacha Old Vines                                             1
# Vinya La Scala Gran Reserva Cabernet Sauvignon                              1
# Ribera Del Duero Gran Reserva                                               1
# Fermentado En Barrica Blanco                                                1
# Cuvee Palomar                                                               1
# Uno Tinto                                                                   1
# Grillo                                                                      1
# 1903 Centenary Grenache                                                     1
# Navarra Reserva Coleccion 125                                               1
# ARX Arcos de la Frontera                                                    1
# Vatan Arena Tinta de Toro                                                   1
# Chardonnay Roure                                                            1
# Perfume de Sonsierra                                                        1
# Galiano Seleccion Especial                                                  1
# Queiron Mi Lugar                                                            1
# Silencio de Miros Ribera Del Duero                                          1
# Senorio de Cuzcurrita Rioja                                                 1
# Pantocrator                                                                 1
# Ekam                                                                        1
# Cerro Anon Rioja Gran Reserva                                               1
# Las Sabias                                                                  1
# Cepas Vellas Godello                                                        1
# Etern Vinyes Molt Velles                                                    1
# Arcos de la Frontera                                                        1
# Nelin Priorat                                                               1
# Syrah (Shiraz)                                                              1
# Vinas Viejas Tempranillo                                                    1
# Vina Garugele                                                               1
# Vitium Reserva                                                              1
# Vintage Albarino                                                            1
# Finca Misenhora Edicion Limitada                                            1
# No. 20                                                                      1
# Ribera del Duero Tinto                                                      1
# Finca Azaya Premium                                                         1
# Crianza Vendimia Seleccionada                                               1
# Rosado de Larrainzar                                                        1
# Altos de Losada El Cepon                                                    1
# Flor de Primavera Peraj Ha'abib                                             1
# Coleccion Syrah                                                             1
# Aurea                                                                       1
# Pancrudo                                                                    1
# Julia                                                                       1
# Respublica Verdejo                                                          1
# III a.C                                                                     1
# Solar de Estraunza Reserva                                                  1
# La Plazuela                                                                 1
# Palmeri Navalta Garnacha                                                    1
# Tras da Vina Albarino                                                       1
# Uro                                                                         1
# Punta Esencia                                                               1
# Giro de Abargues                                                            1
# Vina Motulleri                                                              1
# Finca Matambres                                                             1
# Lo Cabalo Reserva                                                           1
# 40 Aniversario Gran Reserva                                                 1
# Corpinnat Enoteca Reserva Particular de Recaredo                            1
# Brega Garnacha                                                              1
# Finca Biniagual Veran                                                       1
# El Canto del Angel                                                          1
# San Valentin Parellada                                                      1
# Silvanus Edicion Limitada Ribera del Duero                                  1
# El Jardin de las Iguales Vinedo Historico Garnacha                          1
# Garnacha Vinas Centenarias                                                  1
# Alma Tobia Blanco                                                           1
# Zona Zepa Monastrell                                                        1
# Cava Gran Reserva Familiar Millenium Brut                                   1
# Pago de Las Costanas                                                        1
# Casta Diva Cosecha Miel Moscatel Dulce                                      1
# Merlot - Syrah                                                              1
# La Navilla                                                                  1
# Vobiscum                                                                    1
# Carinena Parcela 15 Vinas Viejas                                            1
# Rioja Blanco Reserva                                                        1
# Onomastica Rioja Reserva                                                    1
# Sao Expressiu                                                               1
# Los Dominios de Berceo Prefiloxerico                                        1
# Cava El Tros Nou Pinot Noir                                                 1
# La Baixada                                                                  1
# Oscar Tobia Gran Reserva Rioja                                              1
# Valcavado de Traslascuestas                                                 1
# Ekam Essencia                                                               1
# Finca El Canto                                                              1
# Barrica                                                                     1
# Tm                                                                          1
# Alma Tobia Rioja                                                            1
# Mironia Black Edition Tempranillo                                           1
# Los Tabaqueros                                                              1
# Finca Iscorta Gran Reserva                                                  1
# Don Miguel Comenge Reserva                                                  1
# Millenium Gran Reserva                                                      1
# Godina Garnacha                                                             1
# Gran Vino Albarino                                                          1
# Ribera Del Duero Gran Reserva 12 Anos                                       1
# Fagus de Coto de Hayas Garnacha                                             1
# Tierra Alta de 2 Cotas Reserva                                              1
# Familia Comenge Reserva                                                     1
# Que Bonito Cacareaba Blanco                                                 1
# Torre Albeniz Reserva Ribera del Duero                                      1
# Rioja Vina Coqueta                                                          1
# 8000                                                                        1
# Territorio Luthier Reserva                                                  1
# Finca Martelo                                                               1
# Seleccion La Aguilera                                                       1
# Don PX Vieja Cosecha                                                        1
# Alenza Ribera del Duero Gran Reserva                                        1
# Ribas de Cabrera                                                            1
# Cenit                                                                       1
# La Baraja                                                                   1
# Magico                                                                      1
# Mas del Serral                                                              1
# Vina Tondonia Gran Reserva Blanco                                           1
# Valdafoz Bierzo (Corullon)                                                  1
# Name: wine, dtype: int64
#
# Value counts for region:
# Rioja                              2440
# Ribera del Duero                   1412
# Priorato                            686
# Toro                                300
# Vino de Espana                      261
# Rias Baixas                         252
# Bierzo                              243
# Mallorca                            237
# Alicante                            233
# Costers del Segre                   232
# Ribeiro                             230
# El Terrerazo                        222
# Castilla y Leon                      51
# Cava                                 34
# Jumilla                              26
# Emporda                              25
# Sardon de Duero                      24
# Montilla-Moriles                     23
# Penedes                              22
# Montsant                             20
# Rueda                                17
# Campo de Borja                       16
# Somontano                            15
# Rioja Alta                           14
# Navarra                              11
# Valdeorras                           10
# Valencia                             10
# Cataluna                              9
# Castilla                              8
# Utiel-Requena                         8
# Yecla                                 8
# Rioja Alavesa                         7
# Almansa                               7
# Cadiz                                 7
# Conca de Barbera                      6
# Malaga                                5
# Pla de Bages                          5
# Sierras de Malaga                     5
# Dominio de Valdepusa                  4
# Andalucia                             4
# Alella                                4
# Arinzano                              3
# Gran Canaria                          3
# Mentrida                              3
# Dehesa del Carrizal                   3
# Ribeira Sacra                         3
# Carinena                              3
# Madrid                                3
# Jerez Pedro Ximenes (PX)              2
# La Palma                              2
# Jerez Palo Cortado                    2
# Galicia                               2
# Cigales                               2
# La Mancha                             2
# Extremadura                           2
# Jerez-Xeres-Sherry                    2
# Calatayud                             2
# Aragon                                2
# Pago Calzadilla                       2
# Pla i Llevant                         2
# Binissalem-Mallorca                   1
# Tierra del Vino de Zamora             1
# Ribera del Gallego-Cinco Villas       1
# Murcia                                1
# Monterrei                             1
# Otazu                                 1
# Valdejalon                            1
# Terra Alta                            1
# Arribes                               1
# Condado de Huelva                     1
# Abona                                 1
# Tarragona                             1
# Name: region, dtype: int64
#
# Value counts for type:
# Rioja Red               2357
# Ribera Del Duero Red    1406
# Red                      863
# Priorat Red              674
# Toro Red                 296
# Tempranillo              290
# Albarino                 252
# Mencia                   235
# Rioja White               92
# Grenache                  35
# Cava                      33
# Verdejo                   27
# Pedro Ximenez             27
# Monastrell                18
# Montsant Red              17
# Syrah                     15
# Chardonnay                13
# Cabernet Sauvignon        11
# Sparkling                  5
# Sauvignon Blanc            4
# Sherry                     2
# Name: type, dtype: int64

# %%
#Using Feature Engineering to simplify the 'type' column.
#We will replace any type of wine that contains red with Red.
#I also used google to find some outliers to add to this list.
targets=['red','Tempranillo','Mencia','Grenache','Monastrell','Syrah','Cabernet Sauvignon']
ml_df['type']=np.where(ml_df['type'].str.contains('|'.join(targets),case=False),'Red',ml_df['type'])
eda_df['type']=np.where(eda_df['type'].str.contains('|'.join(targets),case=False),'Red',eda_df['type'])

# %%
#Doing the same for White Wines
targets=['Albarino','Rioja White','Pedro Ximenez','Verdejo','Chardonnay','Sauvignon Blanc','Sherry']
ml_df['type']=np.where(ml_df['type'].str.contains('|'.join(targets),case=False),'White',ml_df['type'])
eda_df['type']=np.where(eda_df['type'].str.contains('|'.join(targets),case=False),'White',eda_df['type'])

# %%
#Finally for Cava to become sparkling wine. We will use a simple code.
ml_df['type'].replace('Cava','Sparkling',inplace=True)
eda_df['type'].replace('Cava','Sparkling',inplace=True)

# %%
#Confirm this worked.
ml_df['type'].value_counts()
eda_df['type'].value_counts()
# Out:
# Red          6755
# White         417
# Sparkling      38
# Name: type, dtype: int64

# %%
#Dropping winery as it only has one category above 6%, just slightly.
ml_df.drop(columns='winery',inplace=True)
eda_df.drop(columns='winery',inplace=True)

# %%
#Create a list for Categorical data
cat_col=eda_df.select_dtypes(['object']).columns
cat_col
# Out:
# Index(['wine', 'region', 'type', 'ratingclass'], dtype='object')

# %%
#Using a loop to find bad categorical data.
totalrows=len(eda_df)
for column in cat_col:
    value_counts=eda_df[column].value_counts()
    percent=value_counts/totalrows
    badcats=percent[percent < 0.03].index
    print(badcats)
# Out:
# Index(['El Puntido', 'Rioja Blanco', 'Tinto', 'Unico', 'Valbuena 5o',
#        'Priorat', 'Ribera del Duero', 'Unico Reserva Especial Edicion',
#        'Rioja Gran Reserva', 'L'Ermita Velles Vinyes Priorat',
#        ...
#        'Seleccion La Aguilera', 'Don PX Vieja Cosecha',
#        'Alenza Ribera del Duero Gran Reserva', 'Ribas de Cabrera', 'Cenit',
#        'La Baraja', 'Magico', 'Mas del Serral',
#        'Vina Tondonia Gran Reserva Blanco', 'Valdafoz Bierzo (Corullon)'],
#       dtype='object', length=756)
# Index(['Castilla y Leon', 'Cava', 'Jumilla', 'Emporda', 'Sardon de Duero',
#        'Montilla-Moriles', 'Penedes', 'Montsant', 'Rueda', 'Campo de Borja',
#        'Somontano', 'Rioja Alta', 'Navarra', 'Valdeorras', 'Valencia',
#        'Cataluna', 'Castilla', 'Utiel-Requena', 'Yecla', 'Rioja Alavesa',
#        'Almansa', 'Cadiz', 'Conca de Barbera', 'Malaga', 'Pla de Bages',
#        'Sierras de Malaga', 'Dominio de Valdepusa', 'Andalucia', 'Alella',
#        'Arinzano', 'Gran Canaria', 'Mentrida', 'Dehesa del Carrizal',
#        'Ribeira Sacra', 'Carinena', 'Madrid', 'Jerez Pedro Ximenes (PX)',
#        'La Palma', 'Jerez Palo Cortado', 'Galicia', 'Cigales', 'La Mancha',
#        'Extremadura', 'Jerez-Xeres-Sherry', 'Calatayud', 'Aragon',
#        'Pago Calzadilla', 'Pla i Llevant', 'Binissalem-Mallorca',
#        'Tierra del Vino de Zamora', 'Ribera del Gallego-Cinco Villas',
#        'Murcia', 'Monterrei', 'Otazu', 'Valdejalon', 'Terra Alta', 'Arribes',
#        'Condado de Huelva', 'Abona', 'Tarragona'],
#       dtype='object')
# Index(['Sparkling'], dtype='object')
# Index(['High Rating'], dtype='object')

# %%
threshold = 0.03
ml_df=ml_df.groupby('region').filter(lambda x: (x['region'].count() / len(ml_df))>= threshold)
eda_df=eda_df.groupby('region').filter(lambda x: (x['region'].count() / len(eda_df))>= threshold)

# %% [markdown]
# # Exploritory data analysis visualizations

# %%
#Heatmap
corr=eda_df.corr()
plt.style.use('dark_background')
mask=np.triu(np.ones_like(corr))
sns.heatmap(corr,annot=True,mask=mask)
plt.tight_layout();

# %% [markdown]
# # Insights from heatmap we can see a few different things.
# ## Positive Correlations
# * Price and Body show a correlation coefficient of 0.36.
#
# ## Negative Correlations
# * Year and Price show a negative correlation coefficient of -0.47.
#
# ### From these insights, we can conclude that price is directly affected by the wine's body.
# ### We can also observe that Year and Price do not drastically affect the price.

# %% [markdown]
# # Exploratory Data Analysis
#
# ### Box Plots for continuous data

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(8,5))
ax=sns.boxplot(data=eda_df,x='rating',y='body')
plt.tight_layout();

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(8,5))
ax=sns.boxplot(data=eda_df,x='rating',y='acidity')
plt.tight_layout();

# %%
sns.set(style='darkgrid')
plt.style.use('dark_background')
ax=sns.histplot(df['rating'])
ax.set_title('Rating count')
plt.tight_layout();

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(8,5))
ax=sns.lineplot(data=eda_df,x='year',y='rating')
ax.set_title('Rating of Wine Based on Harvest Year of Grapes.')
plt.tight_layout();

# %%
plt.figure(figsize=(8,8))
sns.set(style='darkgrid')
ax=sns.boxplot(data=eda_df,x='rating',y='price',orient="v")
plt.tight_layout()
ax.set_title('Rating and Price');

# %%
sns.set(style='darkgrid')
plt.style.use('dark_background')
ax=sns.barplot(data=eda_df,x='rating',y='num_reviews')
ax.set_title('Rating and Number of Reviews')
plt.tight_layout();

# %% [markdown]
# #Outliers May Include
#
# *   Acidity
# *   Body
# *   Number of Reviews
# *   Price

# %% [markdown]
# # Key Trends

# %%
plt.figure(figsize=(20,8))
sns.set_style('darkgrid')
plt.style.use('dark_background')
ax=sns.lineplot(data=eda_df,y='rating',x='year',ci=None,color='cyan')
ax.set_title('Rating of Wine Based on Harvest Year of Grapes.',fontsize=25)
ax.set_xlabel('Year',fontsize=20)
ax.set_ylabel('Rating',fontsize=20)
ax.set_xticks((1930,1940,1950,1960,1970,1980,1990,2000,2010,2020))
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right',fontsize=15)
ax.set_yticklabels(ax.get_yticklabels(),fontsize=15)
plt.tight_layout();

# %% [markdown]
# ### Above line plot shows the drop in rating based on the year grapes were harvested. A significant decline can be seen from 1990 onward.

# %%
plt.figure(figsize=(20,8))
plt.style.use('dark_background')
ax=sns.barplot(data=eda_df,x='year',y='price',ci=None)
ax.set_title('Price by Year of Grape Harvest',fontsize=25)
ax.set_xlabel('Year',fontsize=20)
ax.set_ylabel('Price',fontsize=20)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right',fontsize=15)
ax.set_yticklabels(ax.get_yticklabels(),fontsize=15)
plt.tight_layout();

# %% [markdown]
# ### The above bar plot shows that after the year 1969, almost no wine produced sold for over '1000'. This bit of information seems useful as it may be a grape quality issue, as discussed in our other trend of rating by year of the grape harvest.

# %% [markdown]
# # Modeling

# %%
## Create a function to display the classification metrics of a model
def regression_metrics(model,X_test,y_test,label='Test Data',normalize='true',thresh=.5):                              
    ## Get the predictions
    y_pred = model.predict(X_test)
    y_pred_class = [1 if x > thresh else 0 for x in y_pred]
    print('---' * 20)
    print(f"[i] REGRESSION METRICS FOR: {label}")
    print('---' * 20)
    print(f"R2 Score: {model.score(X_test, y_test):.4f}")
    print(f"Mean Absolute Error: {mean_absolute_error(y_test, y_pred):.6f}")
    print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred):.6f}")
    print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test, y_pred)):.6f}")
    print(f"Explained Variance Score: {explained_variance_score(y_test, y_pred):.6f}")
    print(f"Max Error: {max_error(y_test, y_pred):.6f}")
    plt.show()

# %%
#Reusing previous code to fix bad categorical data in machine learning data set.
mask=ml_df[cat_col].apply(lambda x: x.map(x.value_counts(normalize=True)) >= 0.03).all(axis=1)
ml_df=ml_df[mask]

# %%
# Define Target and Train, Test Split
target=ml_df['rating']
X=ml_df.drop(columns=['rating']).copy()
y=target.copy()
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %%
#Numeric mean imputer
mean_imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
#Scaler
scaler = StandardScaler()
#Pipeline
num_pipeline=make_pipeline(mean_imputer,scaler)
#Selector
num_selector=make_column_selector(dtype_include='number')
#Tuple
numeric_tuple=(num_pipeline, num_selector)

# %%
ml_df.describe(include='object')
# Out:
#            wine region  type ratingclass
# count      5150   5150  5150        5150
# unique       21     12     2           2
# top     Reserva  Rioja   Red  Low Rating
# freq        466   1801  4930        5136

# %%
#Ordered Category Lists
# Populate list with unique categories.
region_list=ml_df['region'].unique().tolist()
wine_list=ml_df['wine'].unique().tolist()
type_list=ml_df['type'].unique().tolist()
categories=[wine_list,region_list,type_list]
#Transformers
orde=OrdinalEncoder(categories=categories,handle_unknown='use_encoded_value',unknown_value=-1)
#We will use a most frequent imputer to impute missing values for the ordinal columns
freq_imputer=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
#We have more than 2 ordinal values for each column so using scaler
scaler2=StandardScaler()
#Pipeline
ord_pipeline=make_pipeline(freq_imputer,orde,scaler2)
#Selector
ordinal_cols=['wine','region','type']
# Tuple
ordinal_tuple=(ord_pipeline,ordinal_cols)

# %%
#Preprocessor
preprocessor=make_column_transformer(ordinal_tuple,numeric_tuple,remainder='drop')
preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['Gran '
#                                                                               'Reserva',
#                                                                               'Reserva',
#                                                                               'Rioja '
#                                                                               'Reserva',
#                                                                               'Valdegines',
#                                                                               'El '
#                                                                               'Viejo',
#                                                                               'Clos '
#                                                                               'del '
#                                                                               'Portal '
#                                                                               'Somni',
#                                                                               'Gran '
#                                                                               'Reserva '
#                                                                               'Rioja',
#                                                                               'Mirto',
#                                                                               'Finca '
#                                                                               'Terrerazo',
#                                                                               'Coleccion '
#                                                                               'Privada',
#                                                                               'Rioja '
#                                                                               'Graciano',...
#                                                                               'Baixas',
#                                                                               'Ribeiro',
#                                                                               'Mallorca'],
#                                                                              ['Red',
#                                                                               'White']],
#                                                                  handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1)),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['wine', 'region', 'type']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])

# %% [markdown]
# # K-Nearest Neighbor Regressor

# %%
#KneighborsRegressor
knn=KNeighborsRegressor()
#Create a pipeline
knn_pipe=make_pipeline(preprocessor,knn)
#Fit
knn_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinalencoder',
#                                                                    OrdinalEncoder(categories=[['Gran '
#                                                                                                'Reserva',
#                                                                                                'Reserva',
#                                                                                                'Rioja '
#                                                                                                'Reserva',
#                                                                                                'Valdegines',
#                                                                                                'El '
#                                                                                                'Viejo',
#                                                                                                'Clos '
#                                                                                                'del '
#                                                                                                'Portal '
#                                                                                                'Somni',
#                                                                                                'Gran '
#                                                                                                'Reserva '
#                                                                                                'Rioja',
#                                                                                                'Mirto',
#                                                                                                'Finca '
#                                                                                                'Terrerazo',
#                                                                                                'C...
#                                                                                   handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1)),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['wine', 'region', 'type']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#                 ('kneighborsregressor', KNeighborsRegressor())])

# %%
#Predict
knnpred_train=knn_pipe.predict(X_train)
knnpred_test=knn_pipe.predict(X_test)

# %%
#Regression Metrics
regression_metrics(knn_pipe, X_test, y_test, label='Test Data K-Nearest Neighbor Regressor')
regression_metrics(knn_pipe, X_train, y_train, label='Training Data K-Nearest Neighbor Regressor')
# Out:
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Test Data K-Nearest Neighbor Regressor
# ------------------------------------------------------------
# R2 Score: 0.6664
# Mean Absolute Error: 0.001262
# Mean Squared Error: 0.000144
# Root Mean Squared Error: 0.012003
# Explained Variance Score: 0.666416
# Max Error: 0.260000
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Training Data K-Nearest Neighbor Regressor
# ------------------------------------------------------------
# R2 Score: 0.7507
# Mean Absolute Error: 0.001155
# Mean Squared Error: 0.000136
# Root Mean Squared Error: 0.011659
# Explained Variance Score: 0.750847
# Max Error: 0.240000

# %%
#Get Params
knn_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('pipeline-1',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('ordinalencoder',
#                                                      OrdinalEncoder(categories=[['Gran '
#                                                                                  'Reserva',
#                                                                                  'Reserva',
#                                                                                  'Rioja '
#                                                                                  'Reserva',
#                                                                                  'Valdegines',
#                                                                                  'El '
#                                                                                  'Viejo',
#                                                                                  'Clos '
#                                                                                  'del '
#                                                                                  'Portal '
#                                                                                  'Somni',
#                                                                                  'Gran '
#                                                                                  'Reserva '
#                                                                                  'Rioja',
#                                                                                  'Mirto',
#                                                                                  'Finca '
#                                                                                  'Terrerazo',
#                                                                                  'Coleccion '
#                                                                                  'Privada',
#                                                                                  'Rioja '
#                                                                                  'Graciano',...
#                                                                                  'Baixas',
#                                                                                  'Ribeiro',
#                                                                                  'Mallorca'],
#                                                                                 ['Red',
#                                                                                  'White']],
#                                                                     handle_unknown='use_encoded_value',
#                                                                     unknown_value=-1)),
#                                                     ('standardscaler',
#                                                      StandardScaler())]),
#                                     ['wine', 'region', 'type']),
#                                    ('pipeline-2',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer()),
#                                                     ('standardscaler',
#                                                      StandardScaler())]),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#   ('kneighborsregressor', KNeighborsRegressor())],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(transformers=[('pipeline-1',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('ordinalencoder',
#                                                    OrdinalEncoder(categories=[['Gran '
#                                                                                'Reserva',
#                                                                                'Reserva',
#                                                                                'Rioja '
#                                                                                'Reserva',
#                                                                                'Valdegines',
#                                                                                'El '
#                                                                                'Viejo',
#                                                                                'Clos '
#                                                                                'del '
#                                                                                'Portal '
#                                                                                'Somni',
#                                                                                'Gran '
#                                                                                'Reserva '
#                                                                                'Rioja',
#                                                                                'Mirto',
#                                                                                'Finca '
#                                                                                'Terrerazo',
#                                                                                'Coleccion '
#                                                                                'Privada',
#                                                                                'Rioja '
#                                                                                'Graciano',...
#                                                                                'Baixas',
#                                                                                'Ribeiro',
#                                                                                'Mallorca'],
#                                                                               ['Red',
#                                                                                'White']],
#                                                                   handle_unknown='use_encoded_value',
#                                                                   unknown_value=-1)),
#                                                   ('standardscaler',
#                                                    StandardScaler())]),
#                                   ['wine', 'region', 'type']),
#                                  ('pipeline-2',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer()),
#                                                   ('standardscaler',
#                                                    StandardScaler())]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)]),
#  'kneighborsregressor': KNeighborsRegressor(),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('pipeline-1',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                    ('ordinalencoder',
#                     OrdinalEncoder(categories=[['Gran Reserva', 'Reserva',
#                                                 'Rioja Reserva', 'Valdegines',
#                                                 'El Viejo',
#                                                 'Clos del Portal Somni',
#                                                 'Gran Reserva Rioja', 'Mirto',
#                                                 'Finca Terrerazo',
#                                                 'Coleccion Privada',
#                                                 'Rioja Graciano',
#                                                 'Altos de Losada',
#                                                 'Vina Alberdi Crianza',
#                                                 'Corimbo I', 'Preludio',
#                                                 'Santa Rosa', 'Roc Nu',
#                                                 'Rias Baixas Albarino Finca '
#                                                 'Valinas',
#                                                 'Treixadura', 'Nounat',
#                                                 'Les Brugueres'],
#                                                ['Ribera del Duero', 'Rioja',
#                                                 'Vino de Espana', 'Toro',
#                                                 'Priorato', 'El Terrerazo',
#                                                 'Bierzo', 'Alicante',
#                                                 'Costers del Segre', 'Rias Baixas',
#                                                 'Ribeiro', 'Mallorca'],
#                                                ['Red', 'White']],
#                                    handle_unknown='use_encoded_value',
#                                    unknown_value=-1)),
#                    ('standardscaler', StandardScaler())]),
#    ['wine', 'region', 'type']),
#   ('pipeline-2',
#    Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                    ('standardscaler', StandardScaler())]),
#    <sklearn.compose._column_transformer.make_column_selector at 0x174f064beb0>)],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': True,
#  'columntransformer__pipeline-1': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('ordinalencoder',
#                   OrdinalEncoder(categories=[['Gran Reserva', 'Reserva',
#                                               'Rioja Reserva', 'Valdegines',
#                                               'El Viejo',
#                                               'Clos del Portal Somni',
#                                               'Gran Reserva Rioja', 'Mirto',
#                                               'Finca Terrerazo',
#                                               'Coleccion Privada',
#                                               'Rioja Graciano',
#                                               'Altos de Losada',
#                                               'Vina Alberdi Crianza',
#                                               'Corimbo I', 'Preludio',
#                                               'Santa Rosa', 'Roc Nu',
#                                               'Rias Baixas Albarino Finca '
#                                               'Valinas',
#                                               'Treixadura', 'Nounat',
#                                               'Les Brugueres'],
#                                              ['Ribera del Duero', 'Rioja',
#                                               'Vino de Espana', 'Toro',
#                                               'Priorato', 'El Terrerazo',
#                                               'Bierzo', 'Alicante',
#                                               'Costers del Segre', 'Rias Baixas',
#                                               'Ribeiro', 'Mallorca'],
#                                              ['Red', 'White']],
#                                  handle_unknown='use_encoded_value',
#                                  unknown_value=-1)),
#                  ('standardscaler', StandardScaler())]),
#  'columntransformer__pipeline-2': Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                  ('standardscaler', StandardScaler())]),
#  'columntransformer__pipeline-1__memory': None,
#  'columntransformer__pipeline-1__steps': [('simpleimputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('ordinalencoder',
#    OrdinalEncoder(categories=[['Gran Reserva', 'Reserva', 'Rioja Reserva',
#                                'Valdegines', 'El Viejo', 'Clos del Portal Somni',
#                                'Gran Reserva Rioja', 'Mirto', 'Finca Terrerazo',
#                                'Coleccion Privada', 'Rioja Graciano',
#                                'Altos de Losada', 'Vina Alberdi Crianza',
#                                'Corimbo I', 'Preludio', 'Santa Rosa', 'Roc Nu',
#                                'Rias Baixas Albarino Finca Valinas', 'Treixadura',
#                                'Nounat', 'Les Brugueres'],
#                               ['Ribera del Duero', 'Rioja', 'Vino de Espana',
#                                'Toro', 'Priorato', 'El Terrerazo', 'Bierzo',
#                                'Alicante', 'Costers del Segre', 'Rias Baixas',
#                                'Ribeiro', 'Mallorca'],
#                               ['Red', 'White']],
#                   handle_unknown='use_encoded_value', unknown_value=-1)),
#   ('standardscaler', StandardScaler())],
#  'columntransformer__pipeline-1__verbose': False,
#  'columntransformer__pipeline-1__simpleimputer': SimpleImputer(strategy='most_frequent'),
#  'columntransformer__pipeline-1__ordinalencoder': OrdinalEncoder(categories=[['Gran Reserva', 'Reserva', 'Rioja Reserva',
#                              'Valdegines', 'El Viejo', 'Clos del Portal Somni',
#                              'Gran Reserva Rioja', 'Mirto', 'Finca Terrerazo',
#                              'Coleccion Privada', 'Rioja Graciano',
#                              'Altos de Losada', 'Vina Alberdi Crianza',
#                              'Corimbo I', 'Preludio', 'Santa Rosa', 'Roc Nu',
#                              'Rias Baixas Albarino Finca Valinas', 'Treixadura',
#                              'Nounat', 'Les Brugueres'],
#                             ['Ribera del Duero', 'Rioja', 'Vino de Espana',
#                              'Toro', 'Priorato', 'El Terrerazo', 'Bierzo',
#                              'Alicante', 'Costers del Segre', 'Rias Baixas',
#                              'Ribeiro', 'Mallorca'],
#                             ['Red', 'White']],
#                 handle_unknown='use_encoded_value', unknown_value=-1),
#  'columntransformer__pipeline-1__standardscaler': StandardScaler(),
#  'columntransformer__pipeline-1__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-1__simpleimputer__copy': True,
#  'columntransformer__pipeline-1__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-1__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline-1__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-1__simpleimputer__strategy': 'most_frequent',
#  'columntransformer__pipeline-1__simpleimputer__verbose': 'deprecated',
#  'columntransformer__pipeline-1__ordinalencoder__categories': [['Gran Reserva',
#    'Reserva',
#    'Rioja Reserva',
#    'Valdegines',
#    'El Viejo',
#    'Clos del Portal Somni',
#    'Gran Reserva Rioja',
#    'Mirto',
#    'Finca Terrerazo',
#    'Coleccion Privada',
#    'Rioja Graciano',
#    'Altos de Losada',
#    'Vina Alberdi Crianza',
#    'Corimbo I',
#    'Preludio',
#    'Santa Rosa',
#    'Roc Nu',
#    'Rias Baixas Albarino Finca Valinas',
#    'Treixadura',
#    'Nounat',
#    'Les Brugueres'],
#   ['Ribera del Duero',
#    'Rioja',
#    'Vino de Espana',
#    'Toro',
#    'Priorato',
#    'El Terrerazo',
#    'Bierzo',
#    'Alicante',
#    'Costers del Segre',
#    'Rias Baixas',
#    'Ribeiro',
#    'Mallorca'],
#   ['Red', 'White']],
#  'columntransformer__pipeline-1__ordinalencoder__dtype': numpy.float64,
#  'columntransformer__pipeline-1__ordinalencoder__encoded_missing_value': nan,
#  'columntransformer__pipeline-1__ordinalencoder__handle_unknown': 'use_encoded_value',
#  'columntransformer__pipeline-1__ordinalencoder__unknown_value': -1,
#  'columntransformer__pipeline-1__standardscaler__copy': True,
#  'columntransformer__pipeline-1__standardscaler__with_mean': True,
#  'columntransformer__pipeline-1__standardscaler__with_std': True,
#  'columntransformer__pipeline-2__memory': None,
#  'columntransformer__pipeline-2__steps': [('simpleimputer', SimpleImputer()),
#   ('standardscaler', StandardScaler())],
#  'columntransformer__pipeline-2__verbose': False,
#  'columntransformer__pipeline-2__simpleimputer': SimpleImputer(),
#  'columntransformer__pipeline-2__standardscaler': StandardScaler(),
#  'columntransformer__pipeline-2__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-2__simpleimputer__copy': True,
#  'columntransformer__pipeline-2__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-2__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline-2__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-2__simpleimputer__strategy': 'mean',
#  'columntransformer__pipeline-2__simpleimputer__verbose': 'deprecated',
#  'columntransformer__pipeline-2__standardscaler__copy': True,
#  'columntransformer__pipeline-2__standardscaler__with_mean': True,
#  'columntransformer__pipeline-2__standardscaler__with_std': True,
#  'kneighborsregressor__algorithm': 'auto',
#  'kneighborsregressor__leaf_size': 30,
#  'kneighborsregressor__metric': 'minkowski',
#  'kneighborsregressor__metric_params': None,
#  'kneighborsregressor__n_jobs': None,
#  'kneighborsregressor__n_neighbors': 5,
#  'kneighborsregressor__p': 2,
#  'kneighborsregressor__weights': 'uniform'}

# %%
params={'kneighborsregressor__n_neighbors':[3,5,7,10,15,20],
        'kneighborsregressor__weights':['uniform','distance'],
        'kneighborsregressor__p': [1, 2]}

# %%
#Create pipeline to find best parameters
gridsearcherknn=GridSearchCV(knn_pipe,params,cv=5)
gridsearcherknn
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ordinalencoder',
#                                                                                           OrdinalEncoder(categories=[['Gran '
#                                                                                                                       'Reserva',
#                                                                                                                       'Reserva',
#                                                                                                                       'Rioja '
#                                                                                                                       'Reserva',
#                                                                                                                       'Valdegines',
#                                                                                                                       'El '
#                                                                                                                       'Viejo',
#                                                                                                                       'Clos '
#                                                                                                                       'del '
#                                                                                                                       'Portal '
#                                                                                                                       'Somni',
#                                                                                                                       'Gran '
#                                                                                                                       'Reserva '
#                                                                                                                       'Rioja',
#                                                                                                                       '...
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#                                        ('kneighborsregressor',
#                                         KNeighborsRegressor())]),
#              param_grid={'kneighborsregressor__n_neighbors': [3, 5, 7, 10, 15,
#                                                               20],
#                          'kneighborsregressor__p': [1, 2],
#                          'kneighborsregressor__weights': ['uniform',
#                                                           'distance']})

# %%
#Fit it
gridsearcherknn.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ordinalencoder',
#                                                                                           OrdinalEncoder(categories=[['Gran '
#                                                                                                                       'Reserva',
#                                                                                                                       'Reserva',
#                                                                                                                       'Rioja '
#                                                                                                                       'Reserva',
#                                                                                                                       'Valdegines',
#                                                                                                                       'El '
#                                                                                                                       'Viejo',
#                                                                                                                       'Clos '
#                                                                                                                       'del '
#                                                                                                                       'Portal '
#                                                                                                                       'Somni',
#                                                                                                                       'Gran '
#                                                                                                                       'Reserva '
#                                                                                                                       'Rioja',
#                                                                                                                       '...
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#                                        ('kneighborsregressor',
#                                         KNeighborsRegressor())]),
#              param_grid={'kneighborsregressor__n_neighbors': [3, 5, 7, 10, 15,
#                                                               20],
#                          'kneighborsregressor__p': [1, 2],
#                          'kneighborsregressor__weights': ['uniform',
#                                                           'distance']})

# %%
#Print best parameters and save them.
print(gridsearcherknn.best_params_)
gridbest_paramsknn=gridsearcherknn.best_estimator_
# Out:
# {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 2, 'kneighborsregressor__weights': 'uniform'}

# %%
#Fit
gridbest_paramsknn.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinalencoder',
#                                                                    OrdinalEncoder(categories=[['Gran '
#                                                                                                'Reserva',
#                                                                                                'Reserva',
#                                                                                                'Rioja '
#                                                                                                'Reserva',
#                                                                                                'Valdegines',
#                                                                                                'El '
#                                                                                                'Viejo',
#                                                                                                'Clos '
#                                                                                                'del '
#                                                                                                'Portal '
#                                                                                                'Somni',
#                                                                                                'Gran '
#                                                                                                'Reserva '
#                                                                                                'Rioja',
#                                                                                                'Mirto',
#                                                                                                'Finca '
#                                                                                                'Terrerazo',
#                                                                                                'C...
#                                                                                   handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1)),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['wine', 'region', 'type']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F066E820>)])),
#                 ('kneighborsregressor', KNeighborsRegressor())])

# %%
# %%time
#Predict on best parameters
bestknn=gridbest_paramsknn.predict(X_test)
bestknn_train=gridbest_paramsknn.predict(X_train)
# Out:
# CPU times: total: 0 ns
# Wall time: 25.9 ms

# %%
#Best Parameters Classification reports
regression_metrics(gridbest_paramsknn,X_test,y_test,label='Test Data K-Nearest Neighbor Regressor')
regression_metrics(gridbest_paramsknn,X_train,y_train,label='Training Data K-Nearest Neighbor Regressor')
# Out:
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Test Data K-Nearest Neighbor Regressor
# ------------------------------------------------------------
# R2 Score: 0.6664
# Mean Absolute Error: 0.001262
# Mean Squared Error: 0.000144
# Root Mean Squared Error: 0.012003
# Explained Variance Score: 0.666416
# Max Error: 0.260000
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Training Data K-Nearest Neighbor Regressor
# ------------------------------------------------------------
# R2 Score: 0.7507
# Mean Absolute Error: 0.001155
# Mean Squared Error: 0.000136
# Root Mean Squared Error: 0.011659
# Explained Variance Score: 0.750847
# Max Error: 0.240000

# %% [markdown]
# # Decision Tree Regressor

# %%
#Decision tree, pipeline for, fit it.
dt=DecisionTreeRegressor()
dt_pipe=make_pipeline(preprocessor,dt)
dt_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinalencoder',
#                                                                    OrdinalEncoder(categories=[['Gran '
#                                                                                                'Reserva',
#                                                                                                'Reserva',
#                                                                                                'Rioja '
#                                                                                                'Reserva',
#                                                                                                'Valdegines',
#                                                                                                'El '
#                                                                                                'Viejo',
#                                                                                                'Clos '
#                                                                                                'del '
#                                                                                                'Portal '
#                                                                                                'Somni',
#                                                                                                'Gran '
#                                                                                                'Reserva '
#                                                                                                'Rioja',
#                                                                                                'Mirto',
#                                                                                                'Finca '
#                                                                                                'Terrerazo',
#                                                                                                'C...
#                                                                                   handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1)),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['wine', 'region', 'type']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#                 ('decisiontreeregressor', DecisionTreeRegressor())])

# %%
#Regression Metrics
regression_metrics(dt_pipe,X_test,y_test,label='Test Data Decision Tree Regressor')
regression_metrics(dt_pipe,X_train,y_train,label='Training Data Decision Tree Regressor')
# Out:
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Test Data Decision Tree Regressor
# ------------------------------------------------------------
# R2 Score: 0.4156
# Mean Absolute Error: 0.001553
# Mean Squared Error: 0.000252
# Root Mean Squared Error: 0.015888
# Explained Variance Score: 0.415639
# Max Error: 0.300000
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Training Data Decision Tree Regressor
# ------------------------------------------------------------
# R2 Score: 1.0000
# Mean Absolute Error: 0.000000
# Mean Squared Error: 0.000000
# Root Mean Squared Error: 0.000000
# Explained Variance Score: 1.000000
# Max Error: 0.000000

# %%
#Get Params
dt_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('pipeline-1',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('ordinalencoder',
#                                                      OrdinalEncoder(categories=[['Gran '
#                                                                                  'Reserva',
#                                                                                  'Reserva',
#                                                                                  'Rioja '
#                                                                                  'Reserva',
#                                                                                  'Valdegines',
#                                                                                  'El '
#                                                                                  'Viejo',
#                                                                                  'Clos '
#                                                                                  'del '
#                                                                                  'Portal '
#                                                                                  'Somni',
#                                                                                  'Gran '
#                                                                                  'Reserva '
#                                                                                  'Rioja',
#                                                                                  'Mirto',
#                                                                                  'Finca '
#                                                                                  'Terrerazo',
#                                                                                  'Coleccion '
#                                                                                  'Privada',
#                                                                                  'Rioja '
#                                                                                  'Graciano',...
#                                                                                  'Baixas',
#                                                                                  'Ribeiro',
#                                                                                  'Mallorca'],
#                                                                                 ['Red',
#                                                                                  'White']],
#                                                                     handle_unknown='use_encoded_value',
#                                                                     unknown_value=-1)),
#                                                     ('standardscaler',
#                                                      StandardScaler())]),
#                                     ['wine', 'region', 'type']),
#                                    ('pipeline-2',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer()),
#                                                     ('standardscaler',
#                                                      StandardScaler())]),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#   ('decisiontreeregressor', DecisionTreeRegressor())],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(transformers=[('pipeline-1',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('ordinalencoder',
#                                                    OrdinalEncoder(categories=[['Gran '
#                                                                                'Reserva',
#                                                                                'Reserva',
#                                                                                'Rioja '
#                                                                                'Reserva',
#                                                                                'Valdegines',
#                                                                                'El '
#                                                                                'Viejo',
#                                                                                'Clos '
#                                                                                'del '
#                                                                                'Portal '
#                                                                                'Somni',
#                                                                                'Gran '
#                                                                                'Reserva '
#                                                                                'Rioja',
#                                                                                'Mirto',
#                                                                                'Finca '
#                                                                                'Terrerazo',
#                                                                                'Coleccion '
#                                                                                'Privada',
#                                                                                'Rioja '
#                                                                                'Graciano',...
#                                                                                'Baixas',
#                                                                                'Ribeiro',
#                                                                                'Mallorca'],
#                                                                               ['Red',
#                                                                                'White']],
#                                                                   handle_unknown='use_encoded_value',
#                                                                   unknown_value=-1)),
#                                                   ('standardscaler',
#                                                    StandardScaler())]),
#                                   ['wine', 'region', 'type']),
#                                  ('pipeline-2',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer()),
#                                                   ('standardscaler',
#                                                    StandardScaler())]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)]),
#  'decisiontreeregressor': DecisionTreeRegressor(),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('pipeline-1',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                    ('ordinalencoder',
#                     OrdinalEncoder(categories=[['Gran Reserva', 'Reserva',
#                                                 'Rioja Reserva', 'Valdegines',
#                                                 'El Viejo',
#                                                 'Clos del Portal Somni',
#                                                 'Gran Reserva Rioja', 'Mirto',
#                                                 'Finca Terrerazo',
#                                                 'Coleccion Privada',
#                                                 'Rioja Graciano',
#                                                 'Altos de Losada',
#                                                 'Vina Alberdi Crianza',
#                                                 'Corimbo I', 'Preludio',
#                                                 'Santa Rosa', 'Roc Nu',
#                                                 'Rias Baixas Albarino Finca '
#                                                 'Valinas',
#                                                 'Treixadura', 'Nounat',
#                                                 'Les Brugueres'],
#                                                ['Ribera del Duero', 'Rioja',
#                                                 'Vino de Espana', 'Toro',
#                                                 'Priorato', 'El Terrerazo',
#                                                 'Bierzo', 'Alicante',
#                                                 'Costers del Segre', 'Rias Baixas',
#                                                 'Ribeiro', 'Mallorca'],
#                                                ['Red', 'White']],
#                                    handle_unknown='use_encoded_value',
#                                    unknown_value=-1)),
#                    ('standardscaler', StandardScaler())]),
#    ['wine', 'region', 'type']),
#   ('pipeline-2',
#    Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                    ('standardscaler', StandardScaler())]),
#    <sklearn.compose._column_transformer.make_column_selector at 0x174f064beb0>)],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': True,
#  'columntransformer__pipeline-1': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('ordinalencoder',
#                   OrdinalEncoder(categories=[['Gran Reserva', 'Reserva',
#                                               'Rioja Reserva', 'Valdegines',
#                                               'El Viejo',
#                                               'Clos del Portal Somni',
#                                               'Gran Reserva Rioja', 'Mirto',
#                                               'Finca Terrerazo',
#                                               'Coleccion Privada',
#                                               'Rioja Graciano',
#                                               'Altos de Losada',
#                                               'Vina Alberdi Crianza',
#                                               'Corimbo I', 'Preludio',
#                                               'Santa Rosa', 'Roc Nu',
#                                               'Rias Baixas Albarino Finca '
#                                               'Valinas',
#                                               'Treixadura', 'Nounat',
#                                               'Les Brugueres'],
#                                              ['Ribera del Duero', 'Rioja',
#                                               'Vino de Espana', 'Toro',
#                                               'Priorato', 'El Terrerazo',
#                                               'Bierzo', 'Alicante',
#                                               'Costers del Segre', 'Rias Baixas',
#                                               'Ribeiro', 'Mallorca'],
#                                              ['Red', 'White']],
#                                  handle_unknown='use_encoded_value',
#                                  unknown_value=-1)),
#                  ('standardscaler', StandardScaler())]),
#  'columntransformer__pipeline-2': Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                  ('standardscaler', StandardScaler())]),
#  'columntransformer__pipeline-1__memory': None,
#  'columntransformer__pipeline-1__steps': [('simpleimputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('ordinalencoder',
#    OrdinalEncoder(categories=[['Gran Reserva', 'Reserva', 'Rioja Reserva',
#                                'Valdegines', 'El Viejo', 'Clos del Portal Somni',
#                                'Gran Reserva Rioja', 'Mirto', 'Finca Terrerazo',
#                                'Coleccion Privada', 'Rioja Graciano',
#                                'Altos de Losada', 'Vina Alberdi Crianza',
#                                'Corimbo I', 'Preludio', 'Santa Rosa', 'Roc Nu',
#                                'Rias Baixas Albarino Finca Valinas', 'Treixadura',
#                                'Nounat', 'Les Brugueres'],
#                               ['Ribera del Duero', 'Rioja', 'Vino de Espana',
#                                'Toro', 'Priorato', 'El Terrerazo', 'Bierzo',
#                                'Alicante', 'Costers del Segre', 'Rias Baixas',
#                                'Ribeiro', 'Mallorca'],
#                               ['Red', 'White']],
#                   handle_unknown='use_encoded_value', unknown_value=-1)),
#   ('standardscaler', StandardScaler())],
#  'columntransformer__pipeline-1__verbose': False,
#  'columntransformer__pipeline-1__simpleimputer': SimpleImputer(strategy='most_frequent'),
#  'columntransformer__pipeline-1__ordinalencoder': OrdinalEncoder(categories=[['Gran Reserva', 'Reserva', 'Rioja Reserva',
#                              'Valdegines', 'El Viejo', 'Clos del Portal Somni',
#                              'Gran Reserva Rioja', 'Mirto', 'Finca Terrerazo',
#                              'Coleccion Privada', 'Rioja Graciano',
#                              'Altos de Losada', 'Vina Alberdi Crianza',
#                              'Corimbo I', 'Preludio', 'Santa Rosa', 'Roc Nu',
#                              'Rias Baixas Albarino Finca Valinas', 'Treixadura',
#                              'Nounat', 'Les Brugueres'],
#                             ['Ribera del Duero', 'Rioja', 'Vino de Espana',
#                              'Toro', 'Priorato', 'El Terrerazo', 'Bierzo',
#                              'Alicante', 'Costers del Segre', 'Rias Baixas',
#                              'Ribeiro', 'Mallorca'],
#                             ['Red', 'White']],
#                 handle_unknown='use_encoded_value', unknown_value=-1),
#  'columntransformer__pipeline-1__standardscaler': StandardScaler(),
#  'columntransformer__pipeline-1__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-1__simpleimputer__copy': True,
#  'columntransformer__pipeline-1__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-1__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline-1__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-1__simpleimputer__strategy': 'most_frequent',
#  'columntransformer__pipeline-1__simpleimputer__verbose': 'deprecated',
#  'columntransformer__pipeline-1__ordinalencoder__categories': [['Gran Reserva',
#    'Reserva',
#    'Rioja Reserva',
#    'Valdegines',
#    'El Viejo',
#    'Clos del Portal Somni',
#    'Gran Reserva Rioja',
#    'Mirto',
#    'Finca Terrerazo',
#    'Coleccion Privada',
#    'Rioja Graciano',
#    'Altos de Losada',
#    'Vina Alberdi Crianza',
#    'Corimbo I',
#    'Preludio',
#    'Santa Rosa',
#    'Roc Nu',
#    'Rias Baixas Albarino Finca Valinas',
#    'Treixadura',
#    'Nounat',
#    'Les Brugueres'],
#   ['Ribera del Duero',
#    'Rioja',
#    'Vino de Espana',
#    'Toro',
#    'Priorato',
#    'El Terrerazo',
#    'Bierzo',
#    'Alicante',
#    'Costers del Segre',
#    'Rias Baixas',
#    'Ribeiro',
#    'Mallorca'],
#   ['Red', 'White']],
#  'columntransformer__pipeline-1__ordinalencoder__dtype': numpy.float64,
#  'columntransformer__pipeline-1__ordinalencoder__encoded_missing_value': nan,
#  'columntransformer__pipeline-1__ordinalencoder__handle_unknown': 'use_encoded_value',
#  'columntransformer__pipeline-1__ordinalencoder__unknown_value': -1,
#  'columntransformer__pipeline-1__standardscaler__copy': True,
#  'columntransformer__pipeline-1__standardscaler__with_mean': True,
#  'columntransformer__pipeline-1__standardscaler__with_std': True,
#  'columntransformer__pipeline-2__memory': None,
#  'columntransformer__pipeline-2__steps': [('simpleimputer', SimpleImputer()),
#   ('standardscaler', StandardScaler())],
#  'columntransformer__pipeline-2__verbose': False,
#  'columntransformer__pipeline-2__simpleimputer': SimpleImputer(),
#  'columntransformer__pipeline-2__standardscaler': StandardScaler(),
#  'columntransformer__pipeline-2__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-2__simpleimputer__copy': True,
#  'columntransformer__pipeline-2__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-2__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline-2__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-2__simpleimputer__strategy': 'mean',
#  'columntransformer__pipeline-2__simpleimputer__verbose': 'deprecated',
#  'columntransformer__pipeline-2__standardscaler__copy': True,
#  'columntransformer__pipeline-2__standardscaler__with_mean': True,
#  'columntransformer__pipeline-2__standardscaler__with_std': True,
#  'decisiontreeregressor__ccp_alpha': 0.0,
#  'decisiontreeregressor__criterion': 'squared_error',
#  'decisiontreeregressor__max_depth': None,
#  'decisiontreeregressor__max_features': None,
#  'decisiontreeregressor__max_leaf_nodes': None,
#  'decisiontreeregressor__min_impurity_decrease': 0.0,
#  'decisiontreeregressor__min_samples_leaf': 1,
#  'decisiontreeregressor__min_samples_split': 2,
#  'decisiontreeregressor__min_weight_fraction_leaf': 0.0,
#  'decisiontreeregressor__random_state': None,
#  'decisiontreeregressor__splitter': 'best'}

# %%
params = {'decisiontreeregressor__max_depth':[None,3,5,7],
          'decisiontreeregressor__min_samples_split':[2,5,10],
          'decisiontreeregressor__min_samples_leaf':[1,2,4],
          'decisiontreeregressor__max_features':['auto','sqrt','log2'],
          'decisiontreeregressor__criterion':['friedman_mse','mse','mae']}

# %%
#Gridsearcher
gridsearcherdt=GridSearchCV(dt_pipe,params)
gridsearcherdt
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ordinalencoder',
#                                                                                           OrdinalEncoder(categories=[['Gran '
#                                                                                                                       'Reserva',
#                                                                                                                       'Reserva',
#                                                                                                                       'Rioja '
#                                                                                                                       'Reserva',
#                                                                                                                       'Valdegines',
#                                                                                                                       'El '
#                                                                                                                       'Viejo',
#                                                                                                                       'Clos '
#                                                                                                                       'del '
#                                                                                                                       'Portal '
#                                                                                                                       'Somni',
#                                                                                                                       'Gran '
#                                                                                                                       'Reserva '
#                                                                                                                       'Rioja',
#                                                                                                                       'Mirto...
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#                                        ('decisiontreeregressor',
#                                         DecisionTreeRegressor())]),
#              param_grid={'decisiontreeregressor__criterion': ['friedman_mse',
#                                                               'mse', 'mae'],
#                          'decisiontreeregressor__max_depth': [None, 3, 5, 7],
#                          'decisiontreeregressor__max_features': ['auto', 'sqrt',
#                                                                  'log2'],
#                          'decisiontreeregressor__min_samples_leaf': [1, 2, 4],
#                          'decisiontreeregressor__min_samples_split': [2, 5,
#                                                                       10]})

# %%
# %%time
#Fit it
gridsearcherdt.fit(X_train,y_train)
# Out:
# CPU times: total: 3.3 s
# Wall time: 13.1 s
# GridSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ordinalencoder',
#                                                                                           OrdinalEncoder(categories=[['Gran '
#                                                                                                                       'Reserva',
#                                                                                                                       'Reserva',
#                                                                                                                       'Rioja '
#                                                                                                                       'Reserva',
#                                                                                                                       'Valdegines',
#                                                                                                                       'El '
#                                                                                                                       'Viejo',
#                                                                                                                       'Clos '
#                                                                                                                       'del '
#                                                                                                                       'Portal '
#                                                                                                                       'Somni',
#                                                                                                                       'Gran '
#                                                                                                                       'Reserva '
#                                                                                                                       'Rioja',
#                                                                                                                       'Mirto...
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#                                        ('decisiontreeregressor',
#                                         DecisionTreeRegressor())]),
#              param_grid={'decisiontreeregressor__criterion': ['friedman_mse',
#                                                               'mse', 'mae'],
#                          'decisiontreeregressor__max_depth': [None, 3, 5, 7],
#                          'decisiontreeregressor__max_features': ['auto', 'sqrt',
#                                                                  'log2'],
#                          'decisiontreeregressor__min_samples_leaf': [1, 2, 4],
#                          'decisiontreeregressor__min_samples_split': [2, 5,
#                                                                       10]})

# %%
#Print best parameters and save them.
print(gridsearcherdt.best_params_)
gridbest_paramsdt=gridsearcherdt.best_estimator_
# Out:
# {'decisiontreeregressor__criterion': 'friedman_mse', 'decisiontreeregressor__max_depth': None, 'decisiontreeregressor__max_features': 'log2', 'decisiontreeregressor__min_samples_leaf': 1, 'decisiontreeregressor__min_samples_split': 10}

# %%
#Fit
gridbest_paramsdt.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinalencoder',
#                                                                    OrdinalEncoder(categories=[['Gran '
#                                                                                                'Reserva',
#                                                                                                'Reserva',
#                                                                                                'Rioja '
#                                                                                                'Reserva',
#                                                                                                'Valdegines',
#                                                                                                'El '
#                                                                                                'Viejo',
#                                                                                                'Clos '
#                                                                                                'del '
#                                                                                                'Portal '
#                                                                                                'Somni',
#                                                                                                'Gran '
#                                                                                                'Reserva '
#                                                                                                'Rioja',
#                                                                                                'Mirto',
#                                                                                                'Finca '
#                                                                                                'Terrerazo',
#                                                                                                'C...
#                                                                    StandardScaler())]),
#                                                   ['wine', 'region', 'type']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F08F6A90>)])),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(criterion='friedman_mse',
#                                        max_features='log2',
#                                        min_samples_split=10))])

# %%
# %%time
#Predict on best parameters
bestdt=gridbest_paramsdt.predict(X_test)
bestdt_train=gridbest_paramsdt.predict(X_train)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 9.47 ms

# %%
#Best Parameters Classification reports
regression_metrics(gridbest_paramsdt,X_test,y_test,label='Test Data Decision Tree Regressor')
regression_metrics(gridbest_paramsdt,X_train,y_train,label='Training Data Decision Tree Regressor')
# Out:
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Test Data Decision Tree Regressor
# ------------------------------------------------------------
# R2 Score: 0.7673
# Mean Absolute Error: 0.001061
# Mean Squared Error: 0.000100
# Root Mean Squared Error: 0.010025
# Explained Variance Score: 0.767511
# Max Error: 0.183333
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Training Data Decision Tree Regressor
# ------------------------------------------------------------
# R2 Score: 0.8969
# Mean Absolute Error: 0.000723
# Mean Squared Error: 0.000056
# Root Mean Squared Error: 0.007496
# Explained Variance Score: 0.896943
# Max Error: 0.175000

# %% [markdown]
# # Random Forest Regressor

# %%
#Model
rfr=RandomForestRegressor()
#Scaler and Model pipeline
rfr_pipe=make_pipeline(preprocessor,rfr)
#Fit model.
rfr_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinalencoder',
#                                                                    OrdinalEncoder(categories=[['Gran '
#                                                                                                'Reserva',
#                                                                                                'Reserva',
#                                                                                                'Rioja '
#                                                                                                'Reserva',
#                                                                                                'Valdegines',
#                                                                                                'El '
#                                                                                                'Viejo',
#                                                                                                'Clos '
#                                                                                                'del '
#                                                                                                'Portal '
#                                                                                                'Somni',
#                                                                                                'Gran '
#                                                                                                'Reserva '
#                                                                                                'Rioja',
#                                                                                                'Mirto',
#                                                                                                'Finca '
#                                                                                                'Terrerazo',
#                                                                                                'C...
#                                                                                   handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1)),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['wine', 'region', 'type']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#                 ('randomforestregressor', RandomForestRegressor())])

# %%
#Regression Metrics
regression_metrics(rfr_pipe,X_test,y_test,label='Test Data Random Forest Regressor')
regression_metrics(rfr_pipe,X_train,y_train,label='Training Data Random Forest Regressor')
# Out:
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Test Data Random Forest Regressor
# ------------------------------------------------------------
# R2 Score: 0.7996
# Mean Absolute Error: 0.001118
# Mean Squared Error: 0.000087
# Root Mean Squared Error: 0.009303
# Explained Variance Score: 0.799631
# Max Error: 0.139000
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Training Data Random Forest Regressor
# ------------------------------------------------------------
# R2 Score: 0.9662
# Mean Absolute Error: 0.000436
# Mean Squared Error: 0.000018
# Root Mean Squared Error: 0.004291
# Explained Variance Score: 0.966221
# Max Error: 0.101000

# %%
#Get Params
rfr_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('pipeline-1',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('ordinalencoder',
#                                                      OrdinalEncoder(categories=[['Gran '
#                                                                                  'Reserva',
#                                                                                  'Reserva',
#                                                                                  'Rioja '
#                                                                                  'Reserva',
#                                                                                  'Valdegines',
#                                                                                  'El '
#                                                                                  'Viejo',
#                                                                                  'Clos '
#                                                                                  'del '
#                                                                                  'Portal '
#                                                                                  'Somni',
#                                                                                  'Gran '
#                                                                                  'Reserva '
#                                                                                  'Rioja',
#                                                                                  'Mirto',
#                                                                                  'Finca '
#                                                                                  'Terrerazo',
#                                                                                  'Coleccion '
#                                                                                  'Privada',
#                                                                                  'Rioja '
#                                                                                  'Graciano',...
#                                                                                  'Baixas',
#                                                                                  'Ribeiro',
#                                                                                  'Mallorca'],
#                                                                                 ['Red',
#                                                                                  'White']],
#                                                                     handle_unknown='use_encoded_value',
#                                                                     unknown_value=-1)),
#                                                     ('standardscaler',
#                                                      StandardScaler())]),
#                                     ['wine', 'region', 'type']),
#                                    ('pipeline-2',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer()),
#                                                     ('standardscaler',
#                                                      StandardScaler())]),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#   ('randomforestregressor', RandomForestRegressor())],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(transformers=[('pipeline-1',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('ordinalencoder',
#                                                    OrdinalEncoder(categories=[['Gran '
#                                                                                'Reserva',
#                                                                                'Reserva',
#                                                                                'Rioja '
#                                                                                'Reserva',
#                                                                                'Valdegines',
#                                                                                'El '
#                                                                                'Viejo',
#                                                                                'Clos '
#                                                                                'del '
#                                                                                'Portal '
#                                                                                'Somni',
#                                                                                'Gran '
#                                                                                'Reserva '
#                                                                                'Rioja',
#                                                                                'Mirto',
#                                                                                'Finca '
#                                                                                'Terrerazo',
#                                                                                'Coleccion '
#                                                                                'Privada',
#                                                                                'Rioja '
#                                                                                'Graciano',...
#                                                                                'Baixas',
#                                                                                'Ribeiro',
#                                                                                'Mallorca'],
#                                                                               ['Red',
#                                                                                'White']],
#                                                                   handle_unknown='use_encoded_value',
#                                                                   unknown_value=-1)),
#                                                   ('standardscaler',
#                                                    StandardScaler())]),
#                                   ['wine', 'region', 'type']),
#                                  ('pipeline-2',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer()),
#                                                   ('standardscaler',
#                                                    StandardScaler())]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)]),
#  'randomforestregressor': RandomForestRegressor(),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('pipeline-1',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                    ('ordinalencoder',
#                     OrdinalEncoder(categories=[['Gran Reserva', 'Reserva',
#                                                 'Rioja Reserva', 'Valdegines',
#                                                 'El Viejo',
#                                                 'Clos del Portal Somni',
#                                                 'Gran Reserva Rioja', 'Mirto',
#                                                 'Finca Terrerazo',
#                                                 'Coleccion Privada',
#                                                 'Rioja Graciano',
#                                                 'Altos de Losada',
#                                                 'Vina Alberdi Crianza',
#                                                 'Corimbo I', 'Preludio',
#                                                 'Santa Rosa', 'Roc Nu',
#                                                 'Rias Baixas Albarino Finca '
#                                                 'Valinas',
#                                                 'Treixadura', 'Nounat',
#                                                 'Les Brugueres'],
#                                                ['Ribera del Duero', 'Rioja',
#                                                 'Vino de Espana', 'Toro',
#                                                 'Priorato', 'El Terrerazo',
#                                                 'Bierzo', 'Alicante',
#                                                 'Costers del Segre', 'Rias Baixas',
#                                                 'Ribeiro', 'Mallorca'],
#                                                ['Red', 'White']],
#                                    handle_unknown='use_encoded_value',
#                                    unknown_value=-1)),
#                    ('standardscaler', StandardScaler())]),
#    ['wine', 'region', 'type']),
#   ('pipeline-2',
#    Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                    ('standardscaler', StandardScaler())]),
#    <sklearn.compose._column_transformer.make_column_selector at 0x174f064beb0>)],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': True,
#  'columntransformer__pipeline-1': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('ordinalencoder',
#                   OrdinalEncoder(categories=[['Gran Reserva', 'Reserva',
#                                               'Rioja Reserva', 'Valdegines',
#                                               'El Viejo',
#                                               'Clos del Portal Somni',
#                                               'Gran Reserva Rioja', 'Mirto',
#                                               'Finca Terrerazo',
#                                               'Coleccion Privada',
#                                               'Rioja Graciano',
#                                               'Altos de Losada',
#                                               'Vina Alberdi Crianza',
#                                               'Corimbo I', 'Preludio',
#                                               'Santa Rosa', 'Roc Nu',
#                                               'Rias Baixas Albarino Finca '
#                                               'Valinas',
#                                               'Treixadura', 'Nounat',
#                                               'Les Brugueres'],
#                                              ['Ribera del Duero', 'Rioja',
#                                               'Vino de Espana', 'Toro',
#                                               'Priorato', 'El Terrerazo',
#                                               'Bierzo', 'Alicante',
#                                               'Costers del Segre', 'Rias Baixas',
#                                               'Ribeiro', 'Mallorca'],
#                                              ['Red', 'White']],
#                                  handle_unknown='use_encoded_value',
#                                  unknown_value=-1)),
#                  ('standardscaler', StandardScaler())]),
#  'columntransformer__pipeline-2': Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                  ('standardscaler', StandardScaler())]),
#  'columntransformer__pipeline-1__memory': None,
#  'columntransformer__pipeline-1__steps': [('simpleimputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('ordinalencoder',
#    OrdinalEncoder(categories=[['Gran Reserva', 'Reserva', 'Rioja Reserva',
#                                'Valdegines', 'El Viejo', 'Clos del Portal Somni',
#                                'Gran Reserva Rioja', 'Mirto', 'Finca Terrerazo',
#                                'Coleccion Privada', 'Rioja Graciano',
#                                'Altos de Losada', 'Vina Alberdi Crianza',
#                                'Corimbo I', 'Preludio', 'Santa Rosa', 'Roc Nu',
#                                'Rias Baixas Albarino Finca Valinas', 'Treixadura',
#                                'Nounat', 'Les Brugueres'],
#                               ['Ribera del Duero', 'Rioja', 'Vino de Espana',
#                                'Toro', 'Priorato', 'El Terrerazo', 'Bierzo',
#                                'Alicante', 'Costers del Segre', 'Rias Baixas',
#                                'Ribeiro', 'Mallorca'],
#                               ['Red', 'White']],
#                   handle_unknown='use_encoded_value', unknown_value=-1)),
#   ('standardscaler', StandardScaler())],
#  'columntransformer__pipeline-1__verbose': False,
#  'columntransformer__pipeline-1__simpleimputer': SimpleImputer(strategy='most_frequent'),
#  'columntransformer__pipeline-1__ordinalencoder': OrdinalEncoder(categories=[['Gran Reserva', 'Reserva', 'Rioja Reserva',
#                              'Valdegines', 'El Viejo', 'Clos del Portal Somni',
#                              'Gran Reserva Rioja', 'Mirto', 'Finca Terrerazo',
#                              'Coleccion Privada', 'Rioja Graciano',
#                              'Altos de Losada', 'Vina Alberdi Crianza',
#                              'Corimbo I', 'Preludio', 'Santa Rosa', 'Roc Nu',
#                              'Rias Baixas Albarino Finca Valinas', 'Treixadura',
#                              'Nounat', 'Les Brugueres'],
#                             ['Ribera del Duero', 'Rioja', 'Vino de Espana',
#                              'Toro', 'Priorato', 'El Terrerazo', 'Bierzo',
#                              'Alicante', 'Costers del Segre', 'Rias Baixas',
#                              'Ribeiro', 'Mallorca'],
#                             ['Red', 'White']],
#                 handle_unknown='use_encoded_value', unknown_value=-1),
#  'columntransformer__pipeline-1__standardscaler': StandardScaler(),
#  'columntransformer__pipeline-1__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-1__simpleimputer__copy': True,
#  'columntransformer__pipeline-1__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-1__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline-1__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-1__simpleimputer__strategy': 'most_frequent',
#  'columntransformer__pipeline-1__simpleimputer__verbose': 'deprecated',
#  'columntransformer__pipeline-1__ordinalencoder__categories': [['Gran Reserva',
#    'Reserva',
#    'Rioja Reserva',
#    'Valdegines',
#    'El Viejo',
#    'Clos del Portal Somni',
#    'Gran Reserva Rioja',
#    'Mirto',
#    'Finca Terrerazo',
#    'Coleccion Privada',
#    'Rioja Graciano',
#    'Altos de Losada',
#    'Vina Alberdi Crianza',
#    'Corimbo I',
#    'Preludio',
#    'Santa Rosa',
#    'Roc Nu',
#    'Rias Baixas Albarino Finca Valinas',
#    'Treixadura',
#    'Nounat',
#    'Les Brugueres'],
#   ['Ribera del Duero',
#    'Rioja',
#    'Vino de Espana',
#    'Toro',
#    'Priorato',
#    'El Terrerazo',
#    'Bierzo',
#    'Alicante',
#    'Costers del Segre',
#    'Rias Baixas',
#    'Ribeiro',
#    'Mallorca'],
#   ['Red', 'White']],
#  'columntransformer__pipeline-1__ordinalencoder__dtype': numpy.float64,
#  'columntransformer__pipeline-1__ordinalencoder__encoded_missing_value': nan,
#  'columntransformer__pipeline-1__ordinalencoder__handle_unknown': 'use_encoded_value',
#  'columntransformer__pipeline-1__ordinalencoder__unknown_value': -1,
#  'columntransformer__pipeline-1__standardscaler__copy': True,
#  'columntransformer__pipeline-1__standardscaler__with_mean': True,
#  'columntransformer__pipeline-1__standardscaler__with_std': True,
#  'columntransformer__pipeline-2__memory': None,
#  'columntransformer__pipeline-2__steps': [('simpleimputer', SimpleImputer()),
#   ('standardscaler', StandardScaler())],
#  'columntransformer__pipeline-2__verbose': False,
#  'columntransformer__pipeline-2__simpleimputer': SimpleImputer(),
#  'columntransformer__pipeline-2__standardscaler': StandardScaler(),
#  'columntransformer__pipeline-2__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-2__simpleimputer__copy': True,
#  'columntransformer__pipeline-2__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-2__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline-2__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-2__simpleimputer__strategy': 'mean',
#  'columntransformer__pipeline-2__simpleimputer__verbose': 'deprecated',
#  'columntransformer__pipeline-2__standardscaler__copy': True,
#  'columntransformer__pipeline-2__standardscaler__with_mean': True,
#  'columntransformer__pipeline-2__standardscaler__with_std': True,
#  'randomforestregressor__bootstrap': True,
#  'randomforestregressor__ccp_alpha': 0.0,
#  'randomforestregressor__criterion': 'squared_error',
#  'randomforestregressor__max_depth': None,
#  'randomforestregressor__max_features': 1.0,
#  'randomforestregressor__max_leaf_nodes': None,
#  'randomforestregressor__max_samples': None,
#  'randomforestregressor__min_impurity_decrease': 0.0,
#  'randomforestregressor__min_samples_leaf': 1,
#  'randomforestregressor__min_samples_split': 2,
#  'randomforestregressor__min_weight_fraction_leaf': 0.0,
#  'randomforestregressor__n_estimators': 100,
#  'randomforestregressor__n_jobs': None,
#  'randomforestregressor__oob_score': False,
#  'randomforestregressor__random_state': None,
#  'randomforestregressor__verbose': 0,
#  'randomforestregressor__warm_start': False}

# %%
params={'randomforestregressor__n_estimators':[100,200,300],
        'randomforestregressor__max_depth':[10,20,30],
        'randomforestregressor__min_samples_split':[2,5,10]}

# %%
#Gridsearcher
gridsearcher_rfr=GridSearchCV(rfr_pipe,params)
gridsearcher_rfr
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ordinalencoder',
#                                                                                           OrdinalEncoder(categories=[['Gran '
#                                                                                                                       'Reserva',
#                                                                                                                       'Reserva',
#                                                                                                                       'Rioja '
#                                                                                                                       'Reserva',
#                                                                                                                       'Valdegines',
#                                                                                                                       'El '
#                                                                                                                       'Viejo',
#                                                                                                                       'Clos '
#                                                                                                                       'del '
#                                                                                                                       'Portal '
#                                                                                                                       'Somni',
#                                                                                                                       'Gran '
#                                                                                                                       'Reserva '
#                                                                                                                       'Rioja',
#                                                                                                                       'Mirto...
#                                                                                           SimpleImputer()),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#                                        ('randomforestregressor',
#                                         RandomForestRegressor())]),
#              param_grid={'randomforestregressor__max_depth': [10, 20, 30],
#                          'randomforestregressor__min_samples_split': [2, 5, 10],
#                          'randomforestregressor__n_estimators': [100, 200,
#                                                                  300]})

# %%
# %%time
#Fit it
gridsearcher_rfr.fit(X_train,y_train)
# Out:
# CPU times: total: 1 s
# Wall time: 26.9 s
# GridSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ordinalencoder',
#                                                                                           OrdinalEncoder(categories=[['Gran '
#                                                                                                                       'Reserva',
#                                                                                                                       'Reserva',
#                                                                                                                       'Rioja '
#                                                                                                                       'Reserva',
#                                                                                                                       'Valdegines',
#                                                                                                                       'El '
#                                                                                                                       'Viejo',
#                                                                                                                       'Clos '
#                                                                                                                       'del '
#                                                                                                                       'Portal '
#                                                                                                                       'Somni',
#                                                                                                                       'Gran '
#                                                                                                                       'Reserva '
#                                                                                                                       'Rioja',
#                                                                                                                       'Mirto...
#                                                                                           SimpleImputer()),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F064BEB0>)])),
#                                        ('randomforestregressor',
#                                         RandomForestRegressor())]),
#              param_grid={'randomforestregressor__max_depth': [10, 20, 30],
#                          'randomforestregressor__min_samples_split': [2, 5, 10],
#                          'randomforestregressor__n_estimators': [100, 200,
#                                                                  300]})

# %%
#Print best parameters and save them.
print(gridsearcher_rfr.best_params_)
gridbest_params_rfr=gridsearcher_rfr.best_estimator_
# Out:
# {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_split': 2, 'randomforestregressor__n_estimators': 100}

# %%
#Fit
gridbest_params_rfr.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinalencoder',
#                                                                    OrdinalEncoder(categories=[['Gran '
#                                                                                                'Reserva',
#                                                                                                'Reserva',
#                                                                                                'Rioja '
#                                                                                                'Reserva',
#                                                                                                'Valdegines',
#                                                                                                'El '
#                                                                                                'Viejo',
#                                                                                                'Clos '
#                                                                                                'del '
#                                                                                                'Portal '
#                                                                                                'Somni',
#                                                                                                'Gran '
#                                                                                                'Reserva '
#                                                                                                'Rioja',
#                                                                                                'Mirto',
#                                                                                                'Finca '
#                                                                                                'Terrerazo',
#                                                                                                'C...
#                                                                                   handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1)),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['wine', 'region', 'type']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000174F078A5B0>)])),
#                 ('randomforestregressor', RandomForestRegressor(max_depth=10))])

# %%
# %%time
#Predict on best parameters
best_rfr=gridbest_params_rfr.predict(X_test)
best_rfr_train=gridbest_params_rfr.predict(X_train)
# Out:
# CPU times: total: 0 ns
# Wall time: 16 ms

# %%
#Best Parameters Classification reports
regression_metrics(gridbest_params_rfr,X_test,y_test,label='Test Data Random Forest Regressor')
regression_metrics(gridbest_params_rfr,X_train,y_train,label='Training Data Random Forest Regressor')
# Out:
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Test Data Random Forest Regressor
# ------------------------------------------------------------
# R2 Score: 0.7663
# Mean Absolute Error: 0.001189
# Mean Squared Error: 0.000101
# Root Mean Squared Error: 0.010047
# Explained Variance Score: 0.766298
# Max Error: 0.163000
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Training Data Random Forest Regressor
# ------------------------------------------------------------
# R2 Score: 0.9616
# Mean Absolute Error: 0.000454
# Mean Squared Error: 0.000021
# Root Mean Squared Error: 0.004576
# Explained Variance Score: 0.961602
# Max Error: 0.123000

# %% [markdown]
# # Production model decision.

# %%
#Best Parameters Classification reports
regression_metrics(gridbest_paramsdt,X_test,y_test,label='Test Data Decision Tree Regressor')
regression_metrics(gridbest_paramsdt,X_train,y_train,label='Training Data Decision Tree Regressor')
# Out:
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Test Data Decision Tree Regressor
# ------------------------------------------------------------
# R2 Score: 0.7673
# Mean Absolute Error: 0.001061
# Mean Squared Error: 0.000100
# Root Mean Squared Error: 0.010025
# Explained Variance Score: 0.767511
# Max Error: 0.183333
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Training Data Decision Tree Regressor
# ------------------------------------------------------------
# R2 Score: 0.8969
# Mean Absolute Error: 0.000723
# Mean Squared Error: 0.000056
# Root Mean Squared Error: 0.007496
# Explained Variance Score: 0.896943
# Max Error: 0.175000

# %%
#Best Parameters Classification reports
regression_metrics(gridbest_paramsknn,X_test,y_test,label='Test Data K-Nearest Neighbor Regressor')
regression_metrics(gridbest_paramsknn,X_train,y_train,label='Training Data K-Nearest Neighbor Regressor')
# Out:
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Test Data K-Nearest Neighbor Regressor
# ------------------------------------------------------------
# R2 Score: 0.6664
# Mean Absolute Error: 0.001262
# Mean Squared Error: 0.000144
# Root Mean Squared Error: 0.012003
# Explained Variance Score: 0.666416
# Max Error: 0.260000
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Training Data K-Nearest Neighbor Regressor
# ------------------------------------------------------------
# R2 Score: 0.7507
# Mean Absolute Error: 0.001155
# Mean Squared Error: 0.000136
# Root Mean Squared Error: 0.011659
# Explained Variance Score: 0.750847
# Max Error: 0.240000

# %%
#Best Parameters Classification reports
regression_metrics(gridbest_params_rfr,X_test,y_test,label='Test Data Random Forest Regressor')
regression_metrics(gridbest_params_rfr,X_train,y_train,label='Training Data Random Forest Regressor')
# Out:
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Test Data Random Forest Regressor
# ------------------------------------------------------------
# R2 Score: 0.7663
# Mean Absolute Error: 0.001189
# Mean Squared Error: 0.000101
# Root Mean Squared Error: 0.010047
# Explained Variance Score: 0.766298
# Max Error: 0.163000
# ------------------------------------------------------------
# [i] REGRESSION METRICS FOR: Training Data Random Forest Regressor
# ------------------------------------------------------------
# R2 Score: 0.9616
# Mean Absolute Error: 0.000454
# Mean Squared Error: 0.000021
# Root Mean Squared Error: 0.004576
# Explained Variance Score: 0.961602
# Max Error: 0.123000

# %% [markdown]
# ## Based on tuned hyperparameters, the Random Forest Regressor seems to be the best option.
#
# * It has the best R2 scores: Train: 0.9642, Test: 0.7953.
# * It has the lowest RMSE
# * The explained variance score is very close to 1, with a value of 0.964161 on the train set, indicating that this model explains a high proportion of the variance.
#
# ### Overall, this model is the best option among the models that were tested.
